# %%
import matplotlib.pyplot as plt
import numpy as np
from read_dat import *
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter


def gaussian(x, mu, sigma, A):
    return (A*(1/(sigma*np.sqrt(2*np.pi)))*np.exp(-(1/2)*((x-mu)/sigma)**2))

# %%
start = -80
long = 520
short = 30

calibration = [0.00007280833261560682, 0.02366570282243352]

dat_file = read_dat('EJ276_50x50_Data/AmBe.dat', align_method='CFD', t_start=start, t_long=long, t_short=short, calibration_m=calibration[0], calibration_c=calibration[1])
# Out:
# init complete

# %%
dat_file.lst_out(100000, ch=[0], output=[[1,1,0,0,0]], filename=f'EJ276_50x50_Data/AmBe_out_for_cuts.csv')
# Out:
# 1000 events
# 1000 events
# 2000 events
# 3000 events
# 4000 events
# 5000 events
# 6000 events
# 7000 events
# 8000 events
# 9000 events
# 10000 events
# 11000 events
# 12000 events
# 13000 events
# 14000 events
# 15000 events
# 16000 events
# 17000 events
# 18000 events
# 19000 events
# 20000 events
# 21000 events
# 22000 events
# 23000 events
# 24000 events
# 25000 events
# 26000 events
# 27000 events
# 28000 events
# 29000 events
# 30000 events
# 31000 events
# 32000 events
# 33000 events
# 34000 events
# 35000 events
# 36000 events
# 37000 events
# 38000 events
# 39000 events
# 40000 events
# 41000 events
# 42000 events
# 43000 events
# 44000 events
# 45000 events
# 46000 events
# 47000 events
# 48000 events
# 49000 events
# 50000 events
# 51000 events
# 52000 events
# 53000 events
# 54000 events
# 55000 events
# 56000 events
# 57000 events
# 58000 events
# 59000 events
# 60000 events
# 61000 events
# 62000 events
# 63000 events
# 64000 events
# 65000 events
# 66000 events
# 67000 events
# 68000 events
# 69000 events
# 70000 events
# 71000 events
# 72000 events
# 73000 events
# 73000 events
# 74000 events
# 75000 events
# 76000 events
# 77000 events
# 78000 events
# 79000 events
# 80000 events
# 81000 events
# 82000 events
# 83000 events
# 84000 events
# 85000 events
# 86000 events
# 87000 events
# 88000 events
# 89000 events
# 90000 events
# 91000 events
# 92000 events
# 93000 events
# 94000 events
# 95000 events
# 96000 events
# 97000 events
# 98000 events
# 99000 events
# 100000 events
# End reading

# %%
file = open(f'./EJ276_50x50_Data/AmBe_out_for_cuts.csv', 'r')

reader = csv.reader(file)

head = next(reader, None)
print(head)
head = next(reader, None)
print(head)

L_for_cut = []
S_for_cut = []

for row in reader:
    L_for_cut.append(float(row[0]))
    S_for_cut.append(float(row[1]))

L_for_cut = np.array(L_for_cut)
S_for_cut = np.array(S_for_cut)
# Out:
# ['EJ276_50x50_Data/AmBe channel 0, 100000 events, cuts False']
# ['L [ch]', 'S[ch]']

# %%
# %matplotlib tk
dat_file.add_selections(L_for_cut, S_for_cut, mode='m', lims=[[0,8], [0,1.2]])
# dat_file.add_selections(mode='p', file='./EJ276_50x50_Data/AmBe_cuts.csv')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Begin selection for cut 1
# 3.0510752688172036 0.7919716646989373
# 1.915322580645161 0.7809523809523808
# 1.397849462365591 0.7715072805981895
# Press X to end the current selection and then D to delete the whole selection!
# End selection
# 0
# Begin selection for cut 1
# 3.2862903225806446 0.7888232979142069
# 2.09005376344086 0.7841007477371112
# 1.4448924731182795 0.7762298307752852
# 1.108870967741935 0.7699330972058244
# 0.8669354838709675 0.7652105470287287
# 0.5309139784946235 0.7463203463203462
# 0.24193548387096753 0.7038173947264855
# 0.14784946236559127 0.6502951593860684
# 0.3629032258064515 0.18748524203069655
# 5.994623655913978 0.12136953955135771
# 7.694892473118278 0.7415977961432506
# 6.881720430107526 0.7888232979142069
# 4.959677419354838 0.7935458480913025
# 3.7634408602150535 0.7841007477371112
# 3.4341397849462365 0.7903974813065721
# End selection
# Polygons Created

# %%
dat_file.reinitialise_file()
dat_file.lst_out(False, output=[[1,1,0,0,0]], cuts=[0], inc=[-1], filename='AmBe_neutron_out.csv')
# Out:
# 1000 events
# 1000 events
# 1000 events
# 2000 events
# 2000 events
# 3000 events
# 3000 events
# 4000 events
# 4000 events
# 4000 events
# 4000 events
# 4000 events
# 4000 events
# 5000 events
# 5000 events
# 6000 events
# 7000 events
# 8000 events
# 9000 events
# 10000 events
# 11000 events
# 12000 events
# 12000 events
# 12000 events
# 13000 events
# 13000 events
# 13000 events
# 13000 events
# 14000 events
# 14000 events
# 15000 events
# 16000 events
# 17000 events
# 18000 events
# 18000 events
# 19000 events
# 20000 events
# 21000 events
# 22000 events
# 23000 events
# 24000 events
# 24000 events
# 24000 events
# 25000 events
# 26000 events
# 27000 events
# 28000 events
# 29000 events
# 30000 events
# 30000 events
# 31000 events
# 32000 events
# 32000 events
# 33000 events
# 33000 events
# 34000 events
# 35000 events
# 36000 events
# 37000 events
# 37000 events
# 38000 events
# 38000 events
# 38000 events
# 38000 events
# 38000 events
# 38000 events
# 39000 events
# 40000 events
# 40000 events
# 40000 events
# 41000 events
# 41000 events
# 41000 events
# 42000 events
# 43000 events
# 43000 events
# 44000 events
# 45000 events
# 45000 events
# 46000 events
# 46000 events
# 46000 events
# 47000 events
# 48000 events
# 48000 events
# 48000 events
# 49000 events
# 49000 events
# 50000 events
# 50000 events
# 50000 events
# 50000 events
# 50000 events
# 50000 events
# 51000 events
# 52000 events
# 52000 events
# 52000 events
# 53000 events
# 54000 events
# 55000 events
# 56000 events
# 57000 events
# 58000 events
# 59000 events
# 60000 events
# 61000 events
# 61000 events
# 62000 events
# 62000 events
# 63000 events
# 64000 events
# 64000 events
# 64000 events
# 65000 events
# 66000 events
# 67000 events
# 68000 events
# 68000 events
# 69000 events
# 70000 events
# 70000 events
# 70000 events
# 71000 events
# 72000 events
# 72000 events
# 73000 events
# 74000 events
# 75000 events
# 75000 events
# 76000 events
# 77000 events
# 77000 events
# 78000 events
# 79000 events
# 79000 events
# 79000 events
# 79000 events
# 79000 events
# 80000 events
# 81000 events
# 82000 events
# 83000 events
# 84000 events
# 84000 events
# 85000 events
# 85000 events
# 85000 events
# 86000 events
# 87000 events
# 88000 events
# 89000 events
# 90000 events
# 91000 events
# 91000 events
# 91000 events
# 92000 events
# 92000 events
# 92000 events
# 93000 events
# 93000 events
# 94000 events
# 94000 events
# 94000 events
# 94000 events
# 95000 events
# 95000 events
# 96000 events
# 97000 events
# 97000 events
# 98000 events
# 98000 events
# 98000 events
# 99000 events
# 99000 events
# 100000 events
# 101000 events
# 102000 events
# 103000 events
# 103000 events
# 104000 events
# 104000 events
# 105000 events
# 106000 events
# 106000 events
# 107000 events
# 108000 events
# 108000 events
# 109000 events
# 110000 events
# 110000 events
# 111000 events
# 112000 events
# 113000 events
# 113000 events
# 113000 events
# 114000 events
# 115000 events
# 115000 events
# 115000 events
# 115000 events
# 116000 events
# 117000 events
# 117000 events
# 118000 events
# 119000 events
# 120000 events
# 121000 events
# 121000 events
# 121000 events
# 122000 events
# 122000 events
# 123000 events
# 123000 events
# 124000 events
# 124000 events
# 125000 events
# 126000 events
# 127000 events
# 128000 events
# 129000 events
# 130000 events
# 131000 events
# 132000 events
# 133000 events
# 134000 events
# 135000 events
# 136000 events
# 137000 events
# 137000 events
# 138000 events
# 139000 events
# 139000 events
# 139000 events
# 139000 events
# 139000 events
# 140000 events
# 141000 events
# 142000 events
# 143000 events
# 143000 events
# 144000 events
# 145000 events
# 146000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 148000 events
# 148000 events
# 149000 events
# 150000 events
# 150000 events
# 150000 events
# 150000 events
# 151000 events
# 152000 events
# 152000 events
# 153000 events
# 153000 events
# 153000 events
# 153000 events
# 153000 events
# 153000 events
# 154000 events
# 154000 events
# 155000 events
# 156000 events
# 157000 events
# 157000 events
# 158000 events
# 158000 events
# 159000 events
# 160000 events
# 161000 events
# 162000 events
# 162000 events
# 162000 events
# 162000 events
# 163000 events
# 163000 events
# 164000 events
# 165000 events
# 166000 events
# 167000 events
# 168000 events
# 168000 events
# 168000 events
# 169000 events
# 169000 events
# 169000 events
# 170000 events
# 170000 events
# 170000 events
# 170000 events
# 171000 events
# 172000 events
# 173000 events
# 173000 events
# 174000 events
# 175000 events
# 175000 events
# 176000 events
# 176000 events
# 177000 events
# 177000 events
# 178000 events
# 179000 events
# 180000 events
# 180000 events
# 181000 events
# 181000 events
# 181000 events
# 181000 events
# 181000 events
# 181000 events
# 182000 events
# 183000 events
# 183000 events
# 184000 events
# 184000 events
# 184000 events
# 185000 events
# 186000 events
# 187000 events
# 187000 events
# 188000 events
# 189000 events
# 189000 events
# 189000 events
# 189000 events
# 190000 events
# 191000 events
# 192000 events
# 192000 events
# 192000 events
# 193000 events
# 193000 events
# 194000 events
# 195000 events
# 196000 events
# 196000 events
# 197000 events
# 198000 events
# 199000 events
# 199000 events
# 200000 events
# 201000 events
# 202000 events
# 203000 events
# 203000 events
# 204000 events
# 205000 events
# 206000 events
# 207000 events
# 207000 events
# 208000 events
# 209000 events
# 210000 events
# 210000 events
# 210000 events
# 211000 events
# 212000 events
# 213000 events
# 213000 events
# 214000 events
# 214000 events
# 215000 events
# 216000 events
# 216000 events
# 217000 events
# 217000 events
# 217000 events
# 218000 events
# 218000 events
# 219000 events
# 219000 events
# 219000 events
# 220000 events
# 220000 events
# 220000 events
# 220000 events
# 220000 events
# 220000 events
# 221000 events
# 221000 events
# 222000 events
# 222000 events
# 223000 events
# 224000 events
# 225000 events
# 225000 events
# 225000 events
# 225000 events
# 226000 events
# 226000 events
# 226000 events
# 227000 events
# 228000 events
# 229000 events
# 230000 events
# 231000 events
# 231000 events
# 231000 events
# 231000 events
# 231000 events
# 232000 events
# 232000 events
# 233000 events
# 233000 events
# 233000 events
# 233000 events
# 234000 events
# 234000 events
# 235000 events
# 236000 events
# 237000 events
# 238000 events
# 239000 events
# 240000 events
# 240000 events
# 240000 events
# 241000 events
# 242000 events
# 243000 events
# 243000 events
# 243000 events
# 244000 events
# 244000 events
# 244000 events
# 245000 events
# 245000 events
# 245000 events
# 246000 events
# 246000 events
# 246000 events
# 246000 events
# 246000 events
# 246000 events
# 247000 events
# 247000 events
# 247000 events
# 247000 events
# 248000 events
# 249000 events
# 250000 events
# 250000 events
# 250000 events
# 250000 events
# 250000 events
# 251000 events
# 251000 events
# 251000 events
# 251000 events
# 252000 events
# 253000 events
# 253000 events
# 254000 events
# 254000 events
# 255000 events
# 256000 events
# 257000 events
# 258000 events
# 258000 events
# 258000 events
# 258000 events
# 258000 events
# 259000 events
# 260000 events
# 261000 events
# 262000 events
# 263000 events
# 264000 events
# 264000 events
# 265000 events
# 266000 events
# 267000 events
# 267000 events
# 268000 events
# 269000 events
# 269000 events
# 269000 events
# 269000 events
# 270000 events
# 270000 events
# 271000 events
# 272000 events
# 272000 events
# 273000 events
# 273000 events
# 273000 events
# 273000 events
# 273000 events
# 274000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 276000 events
# 277000 events
# 277000 events
# 278000 events
# 279000 events
# 280000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 282000 events
# 283000 events
# 284000 events
# 285000 events
# 285000 events
# 286000 events
# 286000 events
# 287000 events
# 288000 events
# 289000 events
# 289000 events
# 290000 events
# 291000 events
# 292000 events
# 292000 events
# 292000 events
# 292000 events
# 293000 events
# 294000 events
# 295000 events
# 295000 events
# 295000 events
# 295000 events
# 296000 events
# 296000 events
# 296000 events
# 297000 events
# 298000 events
# 298000 events
# 299000 events
# 300000 events
# 301000 events
# 301000 events
# 302000 events
# 303000 events
# 304000 events
# 305000 events
# 306000 events
# 307000 events
# 307000 events
# 307000 events
# 308000 events
# 309000 events
# 310000 events
# 310000 events
# 311000 events
# 311000 events
# 312000 events
# 313000 events
# 313000 events
# 313000 events
# 313000 events
# 314000 events
# 314000 events
# 315000 events
# 315000 events
# 316000 events
# 316000 events
# 316000 events
# 317000 events
# 318000 events
# 318000 events
# 318000 events
# 319000 events
# 320000 events
# 320000 events
# 320000 events
# 320000 events
# 321000 events
# 322000 events
# 323000 events
# 323000 events
# 323000 events
# 324000 events
# 325000 events
# 326000 events
# 326000 events
# 326000 events
# 326000 events
# 327000 events
# 328000 events
# 329000 events
# 329000 events
# 329000 events
# 329000 events
# 329000 events
# 330000 events
# 330000 events
# 331000 events
# 332000 events
# 332000 events
# 333000 events
# 333000 events
# 333000 events
# 333000 events
# 334000 events
# 335000 events
# 335000 events
# 335000 events
# 336000 events
# 337000 events
# 337000 events
# 337000 events
# 338000 events
# 338000 events
# 339000 events
# 339000 events
# 340000 events
# 341000 events
# 342000 events
# 343000 events
# 343000 events
# 343000 events
# 343000 events
# 344000 events
# 345000 events
# 345000 events
# 346000 events
# 347000 events
# 348000 events
# 348000 events
# 349000 events
# 350000 events
# 351000 events
# 351000 events
# 352000 events
# 352000 events
# 352000 events
# 353000 events
# 354000 events
# 354000 events
# 355000 events
# 355000 events
# 355000 events
# 356000 events
# 357000 events
# 358000 events
# 358000 events
# 359000 events
# 359000 events
# 359000 events
# 359000 events
# 359000 events
# 360000 events
# 361000 events
# 361000 events
# 361000 events
# 361000 events
# 361000 events
# 361000 events
# 362000 events
# 363000 events
# 364000 events
# 364000 events
# 364000 events
# 365000 events
# 365000 events
# 366000 events
# 366000 events
# 367000 events
# 367000 events
# 368000 events
# 368000 events
# 368000 events
# 368000 events
# 369000 events
# 370000 events
# 371000 events
# 372000 events
# 372000 events
# 373000 events
# 374000 events
# 375000 events
# 376000 events
# 376000 events
# 377000 events
# 377000 events
# 377000 events
# 378000 events
# 379000 events
# 379000 events
# 380000 events
# 380000 events
# 381000 events
# 382000 events
# 383000 events
# 383000 events
# 383000 events
# 384000 events
# 385000 events
# 385000 events
# 386000 events
# 387000 events
# 388000 events
# 388000 events
# 389000 events
# 390000 events
# 390000 events
# 390000 events
# 390000 events
# 391000 events
# 391000 events
# 392000 events
# 393000 events
# 393000 events
# 393000 events
# 393000 events
# 394000 events
# 395000 events
# 395000 events
# 396000 events
# 397000 events
# 398000 events
# 399000 events
# 400000 events
# 400000 events
# 400000 events
# 401000 events
# 402000 events
# 403000 events
# 404000 events
# 405000 events
# 406000 events
# 406000 events
# 407000 events
# 408000 events
# 409000 events
# 409000 events
# 410000 events
# 411000 events
# 411000 events
# 411000 events
# 412000 events
# 413000 events
# 413000 events
# 414000 events
# 415000 events
# 415000 events
# 416000 events
# 416000 events
# 416000 events
# 416000 events
# 417000 events
# 417000 events
# 417000 events
# 417000 events
# 418000 events
# 418000 events
# 419000 events
# 419000 events
# 420000 events
# 420000 events
# 420000 events
# 421000 events
# 421000 events
# 422000 events
# 422000 events
# 422000 events
# 422000 events
# 422000 events
# 423000 events
# 424000 events
# 424000 events
# 425000 events
# 425000 events
# 425000 events
# 426000 events
# 426000 events
# 427000 events
# 428000 events
# 429000 events
# 429000 events
# 430000 events
# 430000 events
# 431000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 433000 events
# 433000 events
# 434000 events
# 434000 events
# 434000 events
# 435000 events
# 435000 events
# 436000 events
# 437000 events
# 437000 events
# 437000 events
# 438000 events
# 438000 events
# 438000 events
# 438000 events
# 438000 events
# 439000 events
# 439000 events
# 440000 events
# 441000 events
# 442000 events
# 443000 events
# 444000 events
# 444000 events
# 444000 events
# 445000 events
# 445000 events
# 446000 events
# 446000 events
# 447000 events
# 448000 events
# 448000 events
# 448000 events
# 449000 events
# 450000 events
# 451000 events
# 451000 events
# 451000 events
# 451000 events
# 451000 events
# 451000 events
# 452000 events
# 452000 events
# 452000 events
# 453000 events
# 453000 events
# 454000 events
# 454000 events
# 454000 events
# 455000 events
# 455000 events
# 456000 events
# 456000 events
# 456000 events
# 456000 events
# 456000 events
# 457000 events
# 457000 events
# 458000 events
# 458000 events
# 459000 events
# 460000 events
# 460000 events
# 460000 events
# 461000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 463000 events
# 464000 events
# 464000 events
# 465000 events
# 466000 events
# 467000 events
# 468000 events
# 469000 events
# 470000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 472000 events
# 473000 events
# 473000 events
# 473000 events
# 473000 events
# 473000 events
# 474000 events
# 474000 events
# 474000 events
# 475000 events
# 475000 events
# 476000 events
# 477000 events
# 478000 events
# 479000 events
# 479000 events
# 479000 events
# 479000 events
# 480000 events
# 480000 events
# 481000 events
# 481000 events
# 481000 events
# 481000 events
# 481000 events
# 481000 events
# 482000 events
# 482000 events
# 483000 events
# 484000 events
# 484000 events
# 484000 events
# 485000 events
# 486000 events
# 487000 events
# 487000 events
# 487000 events
# 487000 events
# 488000 events
# 489000 events
# 489000 events
# 490000 events
# 490000 events
# 491000 events
# 491000 events
# 491000 events
# 492000 events
# 493000 events
# 494000 events
# 495000 events
# 496000 events
# 497000 events
# 498000 events
# 498000 events
# 499000 events
# 499000 events
# 500000 events
# 500000 events
# 500000 events
# 501000 events
# 501000 events
# 501000 events
# 502000 events
# 503000 events
# 504000 events
# 504000 events
# 505000 events
# 505000 events
# 505000 events
# 505000 events
# 506000 events
# 507000 events
# 508000 events
# 509000 events
# 509000 events
# 510000 events
# 510000 events
# 510000 events
# 510000 events
# 511000 events
# 512000 events
# 512000 events
# 513000 events
# 514000 events
# 514000 events
# 515000 events
# 516000 events
# 517000 events
# 518000 events
# 519000 events
# 520000 events
# 520000 events
# 521000 events
# 522000 events
# 522000 events
# 523000 events
# 524000 events
# 524000 events
# 524000 events
# 524000 events
# 525000 events
# 526000 events
# 527000 events
# 527000 events
# 527000 events
# 528000 events
# 529000 events
# 530000 events
# 530000 events
# 530000 events
# 531000 events
# 532000 events
# 532000 events
# 532000 events
# 532000 events
# 533000 events
# 533000 events
# 534000 events
# 535000 events
# 535000 events
# 535000 events
# 535000 events
# 536000 events
# 537000 events
# 537000 events
# 538000 events
# 539000 events
# 540000 events
# 540000 events
# 541000 events
# 541000 events
# 542000 events
# 542000 events
# 543000 events
# 544000 events
# 544000 events
# 544000 events
# 544000 events
# 545000 events
# 546000 events
# 547000 events
# 548000 events
# 548000 events
# 549000 events
# 550000 events
# 551000 events
# 552000 events
# 553000 events
# 553000 events
# 554000 events
# 554000 events
# 555000 events
# 555000 events
# 556000 events
# 557000 events
# 557000 events
# 557000 events
# 557000 events
# 558000 events
# 559000 events
# 560000 events
# 560000 events
# 560000 events
# 561000 events
# 561000 events
# 561000 events
# 561000 events
# 562000 events
# 563000 events
# 563000 events
# 564000 events
# 565000 events
# 566000 events
# 566000 events
# 567000 events
# 567000 events
# 568000 events
# 568000 events
# 569000 events
# 570000 events
# 570000 events
# 570000 events
# 571000 events
# 571000 events
# 572000 events
# 573000 events
# 574000 events
# 574000 events
# 574000 events
# 575000 events
# 575000 events
# 576000 events
# 576000 events
# 577000 events
# 578000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 580000 events
# 581000 events
# 581000 events
# 582000 events
# 582000 events
# 583000 events
# 583000 events
# 583000 events
# 583000 events
# 583000 events
# 584000 events
# 585000 events
# 586000 events
# 586000 events
# 586000 events
# 586000 events
# 587000 events
# 588000 events
# 589000 events
# 590000 events
# 590000 events
# 591000 events
# 592000 events
# 592000 events
# 593000 events
# 594000 events
# 595000 events
# 596000 events
# 596000 events
# 597000 events
# 598000 events
# 599000 events
# 599000 events
# 600000 events
# 601000 events
# 602000 events
# 603000 events
# 603000 events
# 604000 events
# 605000 events
# 606000 events
# 606000 events
# 607000 events
# 608000 events
# 608000 events
# 608000 events
# 609000 events
# 609000 events
# 610000 events
# 610000 events
# 611000 events
# 612000 events
# 612000 events
# 613000 events
# 614000 events
# 615000 events
# 616000 events
# 616000 events
# 617000 events
# 618000 events
# 619000 events
# 619000 events
# 620000 events
# 620000 events
# 621000 events
# 622000 events
# 623000 events
# 624000 events
# 624000 events
# 624000 events
# 625000 events
# 625000 events
# 626000 events
# 626000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 628000 events
# 628000 events
# 628000 events
# 628000 events
# 629000 events
# 630000 events
# 631000 events
# 631000 events
# 631000 events
# 632000 events
# 632000 events
# 633000 events
# 633000 events
# 634000 events
# 634000 events
# 635000 events
# 635000 events
# 636000 events
# 637000 events
# 637000 events
# 637000 events
# 637000 events
# 637000 events
# 637000 events
# 638000 events
# 638000 events
# 639000 events
# 640000 events
# 641000 events
# 642000 events
# 643000 events
# 644000 events
# 645000 events
# 646000 events
# 646000 events
# 647000 events
# 647000 events
# 648000 events
# 649000 events
# 650000 events
# 650000 events
# 650000 events
# 651000 events
# 652000 events
# 653000 events
# 654000 events
# 654000 events
# 654000 events
# 654000 events
# 655000 events
# 655000 events
# 656000 events
# 657000 events
# 657000 events
# 657000 events
# 658000 events
# 658000 events
# 659000 events
# 660000 events
# 661000 events
# 662000 events
# 663000 events
# 663000 events
# 663000 events
# 663000 events
# 664000 events
# 665000 events
# 665000 events
# 666000 events
# 667000 events
# 667000 events
# 668000 events
# 669000 events
# 669000 events
# 670000 events
# 670000 events
# 671000 events
# 671000 events
# 672000 events
# 673000 events
# 673000 events
# 674000 events
# 674000 events
# 675000 events
# 676000 events
# 676000 events
# 676000 events
# 677000 events
# 678000 events
# 679000 events
# 679000 events
# 680000 events
# 681000 events
# 682000 events
# 682000 events
# 682000 events
# 683000 events
# 683000 events
# 684000 events
# 685000 events
# 686000 events
# 686000 events
# 687000 events
# 687000 events
# 687000 events
# 687000 events
# 688000 events
# 688000 events
# 689000 events
# 689000 events
# 690000 events
# 691000 events
# 691000 events
# 691000 events
# 691000 events
# 692000 events
# 693000 events
# 694000 events
# 695000 events
# 695000 events
# 696000 events
# 696000 events
# 697000 events
# 697000 events
# 698000 events
# 698000 events
# 699000 events
# 700000 events
# 701000 events
# 701000 events
# 702000 events
# 703000 events
# 703000 events
# 704000 events
# 704000 events
# 705000 events
# 705000 events
# 706000 events
# 706000 events
# 707000 events
# 707000 events
# 708000 events
# 708000 events
# 708000 events
# 709000 events
# 710000 events
# 711000 events
# 711000 events
# 711000 events
# 712000 events
# 713000 events
# 714000 events
# 715000 events
# 715000 events
# 716000 events
# 717000 events
# 718000 events
# 719000 events
# 720000 events
# 721000 events
# 721000 events
# 722000 events
# 723000 events
# 724000 events
# 725000 events
# 725000 events
# 726000 events
# 727000 events
# 728000 events
# 728000 events
# 729000 events
# 729000 events
# 730000 events
# 730000 events
# 731000 events
# 732000 events
# 733000 events
# 734000 events
# 735000 events
# 735000 events
# 735000 events
# 735000 events
# 736000 events
# 737000 events
# 737000 events
# 738000 events
# 739000 events
# 740000 events
# 740000 events
# 740000 events
# 741000 events
# 742000 events
# 743000 events
# 744000 events
# 745000 events
# 745000 events
# 746000 events
# 747000 events
# 747000 events
# 748000 events
# 749000 events
# 750000 events
# 751000 events
# 751000 events
# 751000 events
# 752000 events
# 753000 events
# 753000 events
# 754000 events
# 754000 events
# 754000 events
# 754000 events
# 755000 events
# 755000 events
# 756000 events
# 757000 events
# 758000 events
# 758000 events
# 758000 events
# 759000 events
# 759000 events
# 760000 events
# 760000 events
# 760000 events
# 761000 events
# 761000 events
# 762000 events
# 762000 events
# 762000 events
# 763000 events
# 763000 events
# 764000 events
# 765000 events
# 766000 events
# 767000 events
# 768000 events
# 768000 events
# 769000 events
# 769000 events
# 769000 events
# 769000 events
# 769000 events
# 769000 events
# 770000 events
# 771000 events
# 771000 events
# 772000 events
# 772000 events
# 772000 events
# 773000 events
# 774000 events
# 775000 events
# 775000 events
# 775000 events
# 775000 events
# 776000 events
# 776000 events
# 776000 events
# 777000 events
# 777000 events
# 778000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 780000 events
# 781000 events
# 781000 events
# 782000 events
# 783000 events
# 783000 events
# 783000 events
# 784000 events
# 784000 events
# 784000 events
# 784000 events
# 784000 events
# 785000 events
# 785000 events
# 786000 events
# 786000 events
# 787000 events
# 788000 events
# 788000 events
# 788000 events
# 789000 events
# 790000 events
# 791000 events
# 791000 events
# 792000 events
# 792000 events
# 793000 events
# 793000 events
# 793000 events
# 793000 events
# 794000 events
# 795000 events
# 796000 events
# 797000 events
# 798000 events
# 798000 events
# 799000 events
# 800000 events
# 800000 events
# 801000 events
# 801000 events
# 802000 events
# 803000 events
# 804000 events
# 804000 events
# 804000 events
# 804000 events
# 805000 events
# 806000 events
# 807000 events
# 807000 events
# 807000 events
# 807000 events
# 808000 events
# 808000 events
# 808000 events
# 808000 events
# 809000 events
# 809000 events
# 809000 events
# 810000 events
# 810000 events
# 811000 events
# 812000 events
# 813000 events
# 814000 events
# 815000 events
# 815000 events
# 815000 events
# 816000 events
# 817000 events
# 818000 events
# 819000 events
# 820000 events
# 821000 events
# 822000 events
# 823000 events
# 823000 events
# 823000 events
# 824000 events
# 824000 events
# 825000 events
# 825000 events
# 826000 events
# 827000 events
# 827000 events
# 827000 events
# 828000 events
# 829000 events
# 830000 events
# 831000 events
# 832000 events
# 832000 events
# 833000 events
# 833000 events
# 834000 events
# 834000 events
# 835000 events
# 835000 events
# 835000 events
# 836000 events
# 837000 events
# 838000 events
# 839000 events
# 839000 events
# 839000 events
# 840000 events
# 840000 events
# 841000 events
# 841000 events
# 842000 events
# 843000 events
# 843000 events
# 843000 events
# 844000 events
# 844000 events
# 845000 events
# 846000 events
# 847000 events
# 847000 events
# 848000 events
# 848000 events
# 849000 events
# 849000 events
# 849000 events
# 850000 events
# 850000 events
# 850000 events
# 850000 events
# 850000 events
# 850000 events
# 851000 events
# 851000 events
# 852000 events
# 853000 events
# 854000 events
# 854000 events
# 855000 events
# 855000 events
# 856000 events
# 856000 events
# 857000 events
# 858000 events
# 858000 events
# 859000 events
# 860000 events
# 860000 events
# 861000 events
# 861000 events
# 861000 events
# 861000 events
# 862000 events
# 862000 events
# 862000 events
# 863000 events
# 864000 events
# 865000 events
# 866000 events
# 867000 events
# 867000 events
# 868000 events
# 869000 events
# 869000 events
# 869000 events
# 870000 events
# 870000 events
# 870000 events
# 870000 events
# 870000 events
# 870000 events
# 871000 events
# 871000 events
# 872000 events
# 873000 events
# 873000 events
# 874000 events
# 874000 events
# 874000 events
# 875000 events
# 876000 events
# 877000 events
# 878000 events
# 879000 events
# 880000 events
# 880000 events
# 881000 events
# 882000 events
# 883000 events
# 884000 events
# 884000 events
# 884000 events
# 885000 events
# 885000 events
# 886000 events
# 886000 events
# 887000 events
# 888000 events
# 888000 events
# 889000 events
# 890000 events
# 891000 events
# 891000 events
# 891000 events
# 891000 events
# 892000 events
# 893000 events
# 894000 events
# 894000 events
# 895000 events
# 896000 events
# 897000 events
# 898000 events
# 899000 events
# 900000 events
# 900000 events
# 901000 events
# 901000 events
# 902000 events
# 903000 events
# 904000 events
# 905000 events
# 906000 events
# 906000 events
# 907000 events
# 907000 events
# 908000 events
# 908000 events
# 908000 events
# 909000 events
# 909000 events
# 910000 events
# 910000 events
# 911000 events
# 911000 events
# 911000 events
# 912000 events
# 913000 events
# 914000 events
# 914000 events
# 915000 events
# 915000 events
# 915000 events
# 916000 events
# 916000 events
# 917000 events
# 918000 events
# 918000 events
# 918000 events
# 918000 events
# 918000 events
# 919000 events
# 919000 events
# 920000 events
# 921000 events
# 922000 events
# 923000 events
# 923000 events
# 924000 events
# 925000 events
# 926000 events
# 926000 events
# 927000 events
# 927000 events
# 927000 events
# 928000 events
# 929000 events
# 930000 events
# 931000 events
# 932000 events
# 933000 events
# 934000 events
# 935000 events
# 935000 events
# 935000 events
# 936000 events
# 937000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 939000 events
# 940000 events
# 940000 events
# 941000 events
# 942000 events
# 942000 events
# 942000 events
# 943000 events
# 943000 events
# 943000 events
# 944000 events
# 945000 events
# 946000 events
# 946000 events
# 947000 events
# 948000 events
# 949000 events
# 949000 events
# 949000 events
# 949000 events
# 950000 events
# 951000 events
# 952000 events
# 952000 events
# 953000 events
# 954000 events
# 954000 events
# 954000 events
# 954000 events
# 955000 events
# 955000 events
# 955000 events
# 955000 events
# 956000 events
# 957000 events
# 958000 events
# 959000 events
# 959000 events
# 960000 events
# 960000 events
# 960000 events
# 961000 events
# 962000 events
# 963000 events
# 964000 events
# 965000 events
# 965000 events
# 965000 events
# 966000 events
# 966000 events
# 967000 events
# 968000 events
# 969000 events
# 970000 events
# 971000 events
# 971000 events
# 971000 events
# 971000 events
# 972000 events
# 973000 events
# 974000 events
# 975000 events
# 976000 events
# 976000 events
# 977000 events
# 977000 events
# 978000 events
# 979000 events
# 980000 events
# 980000 events
# 980000 events
# 980000 events
# 980000 events
# 980000 events
# 981000 events
# 982000 events
# 982000 events
# 983000 events
# 983000 events
# 984000 events
# 985000 events
# 986000 events
# 987000 events
# 987000 events
# 987000 events
# 988000 events
# 988000 events
# 989000 events
# 990000 events
# 990000 events
# 991000 events
# 992000 events
# 992000 events
# 993000 events
# 994000 events
# 995000 events
# 996000 events
# 997000 events
# 998000 events
# 999000 events
# 1000000 events
# 1001000 events
# 1002000 events
# 1003000 events
# 1003000 events
# 1004000 events
# 1005000 events
# 1006000 events
# 1006000 events
# 1006000 events
# 1007000 events
# 1008000 events
# 1009000 events
# 1010000 events
# 1011000 events
# 1011000 events
# 1012000 events
# 1013000 events
# 1014000 events
# 1015000 events
# 1016000 events
# 1017000 events
# 1018000 events
# 1019000 events
# 1019000 events
# 1019000 events
# 1020000 events
# 1021000 events
# 1022000 events
# 1022000 events
# 1023000 events
# 1023000 events
# 1024000 events
# 1025000 events
# 1026000 events
# 1027000 events
# 1028000 events
# 1028000 events
# 1029000 events
# 1030000 events
# 1031000 events
# 1032000 events
# 1033000 events
# 1033000 events
# 1033000 events
# 1033000 events
# 1034000 events
# 1034000 events
# 1034000 events
# 1034000 events
# 1035000 events
# 1036000 events
# 1037000 events
# 1037000 events
# 1038000 events
# 1038000 events
# 1038000 events
# 1039000 events
# 1039000 events
# 1039000 events
# 1040000 events
# 1041000 events
# 1042000 events
# 1042000 events
# 1043000 events
# 1043000 events
# 1044000 events
# 1044000 events
# 1045000 events
# 1046000 events
# 1047000 events
# 1047000 events
# 1048000 events
# 1049000 events
# 1050000 events
# 1050000 events
# 1051000 events
# 1051000 events
# 1051000 events
# 1052000 events
# 1053000 events
# 1053000 events
# 1053000 events
# 1054000 events
# 1055000 events
# 1056000 events
# 1057000 events
# 1058000 events
# 1059000 events
# 1060000 events
# 1060000 events
# 1061000 events
# 1061000 events
# 1062000 events
# 1063000 events
# 1064000 events
# 1064000 events
# 1064000 events
# 1064000 events
# 1065000 events
# 1065000 events
# 1065000 events
# 1066000 events
# 1066000 events
# 1067000 events
# 1068000 events
# 1068000 events
# 1069000 events
# 1070000 events
# 1070000 events
# 1071000 events
# 1072000 events
# 1073000 events
# 1074000 events
# 1074000 events
# 1075000 events
# 1076000 events
# 1076000 events
# 1077000 events
# 1078000 events
# 1079000 events
# 1080000 events
# 1081000 events
# 1081000 events
# 1081000 events
# 1082000 events
# 1082000 events
# 1082000 events
# 1083000 events
# 1083000 events
# 1084000 events
# 1084000 events
# 1085000 events
# 1086000 events
# 1086000 events
# 1087000 events
# 1087000 events
# 1088000 events
# 1088000 events
# 1088000 events
# 1089000 events
# 1090000 events
# 1091000 events
# 1092000 events
# 1092000 events
# 1093000 events
# 1094000 events
# 1095000 events
# 1095000 events
# 1096000 events
# 1096000 events
# 1096000 events
# 1097000 events
# 1098000 events
# 1098000 events
# 1099000 events
# 1099000 events
# 1100000 events
# 1100000 events
# 1101000 events
# 1101000 events
# 1102000 events
# 1102000 events
# 1102000 events
# 1102000 events
# 1103000 events
# 1104000 events
# 1105000 events
# 1106000 events
# 1107000 events
# 1107000 events
# 1108000 events
# 1108000 events
# 1109000 events
# 1110000 events
# 1111000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1113000 events
# 1114000 events
# 1114000 events
# 1114000 events
# 1114000 events
# 1114000 events
# 1115000 events
# 1116000 events
# 1117000 events
# 1118000 events
# 1118000 events
# 1118000 events
# 1119000 events
# 1120000 events
# 1121000 events
# 1122000 events
# 1122000 events
# 1122000 events
# 1123000 events
# 1124000 events
# 1125000 events
# 1126000 events
# 1126000 events
# 1126000 events
# 1126000 events
# 1126000 events
# 1127000 events
# 1127000 events
# 1128000 events
# 1129000 events
# 1130000 events
# 1131000 events
# 1131000 events
# 1132000 events
# 1133000 events
# 1134000 events
# 1135000 events
# 1135000 events
# 1136000 events
# 1137000 events
# 1137000 events
# 1137000 events
# 1138000 events
# 1139000 events
# 1140000 events
# 1141000 events
# 1141000 events
# 1142000 events
# 1143000 events
# 1143000 events
# 1144000 events
# 1145000 events
# 1145000 events
# 1146000 events
# 1146000 events
# 1146000 events
# 1147000 events
# 1147000 events
# 1148000 events
# 1149000 events
# 1150000 events
# 1150000 events
# 1150000 events
# 1151000 events
# 1151000 events
# 1151000 events
# 1152000 events
# 1152000 events
# 1152000 events
# 1152000 events
# 1153000 events
# 1154000 events
# 1154000 events
# 1155000 events
# 1155000 events
# 1155000 events
# 1156000 events
# 1157000 events
# 1157000 events
# 1158000 events
# 1159000 events
# 1160000 events
# 1161000 events
# 1162000 events
# 1162000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1164000 events
# 1164000 events
# 1165000 events
# 1165000 events
# 1166000 events
# 1167000 events
# 1167000 events
# 1167000 events
# 1168000 events
# 1169000 events
# 1169000 events
# 1169000 events
# 1170000 events
# 1171000 events
# 1172000 events
# 1172000 events
# 1173000 events
# 1173000 events
# 1174000 events
# 1174000 events
# 1175000 events
# 1176000 events
# 1176000 events
# 1177000 events
# 1177000 events
# 1177000 events
# 1178000 events
# 1178000 events
# 1179000 events
# 1180000 events
# 1181000 events
# 1181000 events
# 1182000 events
# 1182000 events
# 1183000 events
# 1184000 events
# 1185000 events
# 1185000 events
# 1185000 events
# 1186000 events
# 1187000 events
# 1187000 events
# 1188000 events
# 1188000 events
# 1188000 events
# 1188000 events
# 1189000 events
# 1189000 events
# 1190000 events
# 1191000 events
# 1191000 events
# 1191000 events
# 1192000 events
# 1192000 events
# 1192000 events
# 1193000 events
# 1194000 events
# 1195000 events
# 1196000 events
# 1197000 events
# 1197000 events
# 1198000 events
# 1199000 events
# 1200000 events
# 1200000 events
# 1201000 events
# 1202000 events
# 1202000 events
# 1202000 events
# 1202000 events
# 1202000 events
# 1203000 events
# 1203000 events
# 1204000 events
# 1204000 events
# 1205000 events
# 1205000 events
# 1206000 events
# 1206000 events
# 1207000 events
# 1207000 events
# 1208000 events
# 1209000 events
# 1210000 events
# 1210000 events
# 1211000 events
# 1212000 events
# 1213000 events
# 1213000 events
# 1214000 events
# 1214000 events
# 1215000 events
# 1215000 events
# 1216000 events
# 1217000 events
# 1218000 events
# 1219000 events
# 1220000 events
# 1220000 events
# 1220000 events
# 1221000 events
# 1222000 events
# 1223000 events
# 1224000 events
# 1224000 events
# 1225000 events
# 1226000 events
# 1227000 events
# 1228000 events
# 1229000 events
# 1229000 events
# 1229000 events
# 1230000 events
# 1230000 events
# 1230000 events
# 1230000 events
# 1231000 events
# 1231000 events
# 1232000 events
# 1233000 events
# 1234000 events
# 1235000 events
# 1236000 events
# 1237000 events
# 1237000 events
# 1238000 events
# 1238000 events
# 1239000 events
# 1240000 events
# 1240000 events
# 1241000 events
# 1242000 events
# 1242000 events
# 1243000 events
# 1243000 events
# 1244000 events
# 1244000 events
# 1244000 events
# 1245000 events
# 1246000 events
# 1246000 events
# 1247000 events
# 1248000 events
# 1248000 events
# 1249000 events
# 1250000 events
# 1251000 events
# 1252000 events
# 1252000 events
# 1253000 events
# 1253000 events
# 1254000 events
# 1254000 events
# 1255000 events
# 1256000 events
# 1257000 events
# 1257000 events
# 1257000 events
# 1257000 events
# 1257000 events
# 1258000 events
# 1259000 events
# 1259000 events
# 1259000 events
# 1259000 events
# 1259000 events
# 1260000 events
# 1261000 events
# 1261000 events
# 1262000 events
# 1263000 events
# 1263000 events
# 1263000 events
# 1264000 events
# 1264000 events
# 1265000 events
# 1266000 events
# 1266000 events
# 1266000 events
# 1266000 events
# 1267000 events
# 1268000 events
# 1268000 events
# 1269000 events
# 1269000 events
# 1270000 events
# 1270000 events
# 1271000 events
# 1271000 events
# 1271000 events
# 1272000 events
# 1273000 events
# 1274000 events
# 1274000 events
# 1275000 events
# 1276000 events
# 1276000 events
# 1277000 events
# 1277000 events
# 1277000 events
# 1278000 events
# 1278000 events
# 1279000 events
# 1280000 events
# 1281000 events
# 1282000 events
# 1283000 events
# 1284000 events
# 1284000 events
# 1284000 events
# 1285000 events
# 1285000 events
# 1286000 events
# 1287000 events
# 1288000 events
# 1288000 events
# 1289000 events
# 1290000 events
# 1291000 events
# 1291000 events
# 1291000 events
# 1292000 events
# 1293000 events
# 1293000 events
# 1294000 events
# 1294000 events
# 1295000 events
# 1296000 events
# 1297000 events
# 1297000 events
# 1298000 events
# 1298000 events
# 1298000 events
# 1298000 events
# 1298000 events
# 1299000 events
# 1299000 events
# 1299000 events
# 1299000 events
# 1300000 events
# 1300000 events
# 1301000 events
# 1301000 events
# 1302000 events
# 1302000 events
# 1302000 events
# 1303000 events
# 1303000 events
# 1304000 events
# 1305000 events
# 1305000 events
# 1305000 events
# 1306000 events
# 1307000 events
# 1308000 events
# 1309000 events
# 1309000 events
# 1309000 events
# 1310000 events
# 1310000 events
# 1310000 events
# 1310000 events
# 1311000 events
# 1312000 events
# 1313000 events
# 1313000 events
# 1314000 events
# 1314000 events
# 1314000 events
# 1315000 events
# 1315000 events
# 1315000 events
# 1316000 events
# 1316000 events
# 1317000 events
# 1318000 events
# 1319000 events
# 1319000 events
# 1320000 events
# 1321000 events
# 1322000 events
# 1322000 events
# 1323000 events
# 1324000 events
# 1325000 events
# 1326000 events
# 1327000 events
# 1327000 events
# 1328000 events
# 1328000 events
# 1329000 events
# 1330000 events
# 1331000 events
# 1332000 events
# 1332000 events
# 1333000 events
# 1333000 events
# 1334000 events
# 1334000 events
# 1335000 events
# 1336000 events
# 1337000 events
# 1337000 events
# 1338000 events
# 1338000 events
# 1339000 events
# 1340000 events
# 1340000 events
# 1341000 events
# 1342000 events
# 1342000 events
# 1342000 events
# 1342000 events
# 1343000 events
# 1344000 events
# 1345000 events
# 1345000 events
# 1346000 events
# 1347000 events
# 1348000 events
# 1349000 events
# 1350000 events
# 1351000 events
# 1351000 events
# 1352000 events
# 1353000 events
# 1353000 events
# 1353000 events
# 1354000 events
# 1354000 events
# 1355000 events
# 1356000 events
# 1357000 events
# 1357000 events
# 1358000 events
# 1358000 events
# 1359000 events
# 1360000 events
# 1360000 events
# 1360000 events
# 1360000 events
# 1361000 events
# 1361000 events
# 1361000 events
# 1362000 events
# 1362000 events
# 1363000 events
# 1364000 events
# 1365000 events
# 1365000 events
# 1365000 events
# 1366000 events
# 1367000 events
# 1368000 events
# 1369000 events
# 1370000 events
# 1370000 events
# 1371000 events
# 1372000 events
# 1372000 events
# 1373000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1375000 events
# 1376000 events
# 1377000 events
# 1378000 events
# 1379000 events
# 1379000 events
# 1380000 events
# 1381000 events
# 1382000 events
# 1382000 events
# 1382000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1384000 events
# 1384000 events
# 1384000 events
# 1384000 events
# 1385000 events
# 1385000 events
# 1385000 events
# 1385000 events
# 1386000 events
# 1386000 events
# 1386000 events
# 1387000 events
# 1388000 events
# 1389000 events
# 1389000 events
# 1390000 events
# 1391000 events
# 1391000 events
# 1392000 events
# 1392000 events
# 1393000 events
# 1393000 events
# 1393000 events
# 1394000 events
# 1394000 events
# 1394000 events
# 1394000 events
# 1395000 events
# 1395000 events
# 1396000 events
# 1397000 events
# 1398000 events
# 1399000 events
# 1400000 events
# 1400000 events
# 1401000 events
# 1402000 events
# 1402000 events
# 1402000 events
# 1403000 events
# 1404000 events
# 1404000 events
# 1404000 events
# 1405000 events
# 1405000 events
# 1405000 events
# 1406000 events
# 1406000 events
# 1407000 events
# 1408000 events
# 1409000 events
# 1410000 events
# 1410000 events
# 1411000 events
# 1412000 events
# 1412000 events
# 1413000 events
# 1413000 events
# 1414000 events
# 1415000 events
# 1416000 events
# 1416000 events
# 1416000 events
# 1417000 events
# 1418000 events
# 1419000 events
# 1419000 events
# 1420000 events
# 1421000 events
# 1422000 events
# 1423000 events
# 1423000 events
# 1424000 events
# 1424000 events
# 1425000 events
# 1426000 events
# 1427000 events
# 1428000 events
# 1428000 events
# 1428000 events
# 1428000 events
# 1429000 events
# 1430000 events
# 1431000 events
# 1431000 events
# 1432000 events
# 1433000 events
# 1434000 events
# 1434000 events
# 1434000 events
# 1435000 events
# 1435000 events
# 1436000 events
# 1437000 events
# 1438000 events
# 1438000 events
# 1439000 events
# 1439000 events
# 1440000 events
# 1441000 events
# 1441000 events
# 1442000 events
# 1442000 events
# 1442000 events
# 1442000 events
# 1443000 events
# 1443000 events
# 1444000 events
# 1445000 events
# 1446000 events
# 1447000 events
# 1448000 events
# 1448000 events
# 1448000 events
# 1448000 events
# 1449000 events
# 1450000 events
# 1451000 events
# 1452000 events
# 1452000 events
# 1452000 events
# 1453000 events
# 1453000 events
# 1454000 events
# 1455000 events
# 1456000 events
# 1457000 events
# 1458000 events
# 1459000 events
# 1460000 events
# 1461000 events
# 1462000 events
# 1463000 events
# 1464000 events
# 1465000 events
# 1465000 events
# 1465000 events
# 1466000 events
# 1467000 events
# 1468000 events
# 1469000 events
# 1469000 events
# 1469000 events
# 1470000 events
# 1471000 events
# 1472000 events
# 1472000 events
# 1472000 events
# 1473000 events
# 1474000 events
# 1475000 events
# 1476000 events
# 1477000 events
# 1477000 events
# 1477000 events
# 1477000 events
# 1477000 events
# 1478000 events
# 1479000 events
# 1479000 events
# 1480000 events
# 1481000 events
# 1482000 events
# 1482000 events
# 1483000 events
# 1483000 events
# 1483000 events
# 1484000 events
# 1485000 events
# 1486000 events
# 1487000 events
# 1488000 events
# 1488000 events
# 1488000 events
# 1488000 events
# 1489000 events
# 1490000 events
# 1490000 events
# 1490000 events
# 1491000 events
# 1492000 events
# 1493000 events
# 1493000 events
# 1494000 events
# 1495000 events
# 1496000 events
# 1497000 events
# 1498000 events
# 1498000 events
# 1499000 events
# 1500000 events
# 1500000 events
# 1500000 events
# 1500000 events
# 1500000 events
# 1501000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1503000 events
# 1504000 events
# 1504000 events
# 1505000 events
# 1506000 events
# 1507000 events
# 1507000 events
# 1508000 events
# 1508000 events
# 1509000 events
# 1509000 events
# 1509000 events
# 1510000 events
# 1511000 events
# 1512000 events
# 1513000 events
# 1513000 events
# 1513000 events
# 1514000 events
# 1514000 events
# 1515000 events
# 1516000 events
# 1517000 events
# 1518000 events
# 1518000 events
# 1518000 events
# 1518000 events
# 1519000 events
# 1520000 events
# 1520000 events
# 1521000 events
# 1521000 events
# 1522000 events
# 1523000 events
# 1523000 events
# 1523000 events
# 1524000 events
# 1525000 events
# 1525000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1527000 events
# 1527000 events
# 1528000 events
# 1528000 events
# 1528000 events
# 1529000 events
# 1530000 events
# 1531000 events
# 1532000 events
# 1532000 events
# 1533000 events
# 1533000 events
# 1534000 events
# 1534000 events
# 1535000 events
# 1535000 events
# 1536000 events
# 1537000 events
# 1537000 events
# 1537000 events
# 1538000 events
# 1539000 events
# 1539000 events
# 1540000 events
# 1541000 events
# 1542000 events
# 1543000 events
# 1543000 events
# 1543000 events
# 1543000 events
# 1544000 events
# 1545000 events
# 1546000 events
# 1547000 events
# 1547000 events
# 1548000 events
# 1549000 events
# 1549000 events
# 1550000 events
# 1550000 events
# 1551000 events
# 1552000 events
# 1553000 events
# 1554000 events
# 1554000 events
# 1554000 events
# 1555000 events
# 1555000 events
# 1556000 events
# 1557000 events
# 1558000 events
# 1559000 events
# 1559000 events
# 1559000 events
# 1560000 events
# 1561000 events
# 1561000 events
# 1562000 events
# 1562000 events
# 1563000 events
# 1563000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1565000 events
# 1566000 events
# 1567000 events
# 1568000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1570000 events
# End reading

# %%
dat_file.reinitialise_file()
dat_file.lst_out(False, output=[[1,1,0,0,0]], cuts=[0], inc=[-1], filename='AmBe_gamma_out.csv')
# Out:
# 1000 events
# 1000 events
# 1000 events
# 2000 events
# 2000 events
# 3000 events
# 3000 events
# 4000 events
# 4000 events
# 4000 events
# 4000 events
# 4000 events
# 4000 events
# 5000 events
# 5000 events
# 6000 events
# 7000 events
# 8000 events
# 9000 events
# 10000 events
# 11000 events
# 12000 events
# 12000 events
# 12000 events
# 13000 events
# 13000 events
# 13000 events
# 13000 events
# 14000 events
# 14000 events
# 15000 events
# 16000 events
# 17000 events
# 18000 events
# 18000 events
# 19000 events
# 20000 events
# 21000 events
# 22000 events
# 23000 events
# 24000 events
# 24000 events
# 24000 events
# 25000 events
# 26000 events
# 27000 events
# 28000 events
# 29000 events
# 30000 events
# 30000 events
# 31000 events
# 32000 events
# 32000 events
# 33000 events
# 33000 events
# 34000 events
# 35000 events
# 36000 events
# 37000 events
# 37000 events
# 38000 events
# 38000 events
# 38000 events
# 38000 events
# 38000 events
# 38000 events
# 39000 events
# 40000 events
# 40000 events
# 40000 events
# 41000 events
# 41000 events
# 41000 events
# 42000 events
# 43000 events
# 43000 events
# 44000 events
# 45000 events
# 45000 events
# 46000 events
# 46000 events
# 46000 events
# 47000 events
# 48000 events
# 48000 events
# 48000 events
# 49000 events
# 49000 events
# 50000 events
# 50000 events
# 50000 events
# 50000 events
# 50000 events
# 50000 events
# 51000 events
# 52000 events
# 52000 events
# 52000 events
# 53000 events
# 54000 events
# 55000 events
# 56000 events
# 57000 events
# 58000 events
# 59000 events
# 60000 events
# 61000 events
# 61000 events
# 62000 events
# 62000 events
# 63000 events
# 64000 events
# 64000 events
# 64000 events
# 65000 events
# 66000 events
# 67000 events
# 68000 events
# 68000 events
# 69000 events
# 70000 events
# 70000 events
# 70000 events
# 71000 events
# 72000 events
# 72000 events
# 73000 events
# 74000 events
# 75000 events
# 75000 events
# 76000 events
# 77000 events
# 77000 events
# 78000 events
# 79000 events
# 79000 events
# 79000 events
# 79000 events
# 79000 events
# 80000 events
# 81000 events
# 82000 events
# 83000 events
# 84000 events
# 84000 events
# 85000 events
# 85000 events
# 85000 events
# 86000 events
# 87000 events
# 88000 events
# 89000 events
# 90000 events
# 91000 events
# 91000 events
# 91000 events
# 92000 events
# 92000 events
# 92000 events
# 93000 events
# 93000 events
# 94000 events
# 94000 events
# 94000 events
# 94000 events
# 95000 events
# 95000 events
# 96000 events
# 97000 events
# 97000 events
# 98000 events
# 98000 events
# 98000 events
# 99000 events
# 99000 events
# 100000 events
# 101000 events
# 102000 events
# 103000 events
# 103000 events
# 104000 events
# 104000 events
# 105000 events
# 106000 events
# 106000 events
# 107000 events
# 108000 events
# 108000 events
# 109000 events
# 110000 events
# 110000 events
# 111000 events
# 112000 events
# 113000 events
# 113000 events
# 113000 events
# 114000 events
# 115000 events
# 115000 events
# 115000 events
# 115000 events
# 116000 events
# 117000 events
# 117000 events
# 118000 events
# 119000 events
# 120000 events
# 121000 events
# 121000 events
# 121000 events
# 122000 events
# 122000 events
# 123000 events
# 123000 events
# 124000 events
# 124000 events
# 125000 events
# 126000 events
# 127000 events
# 128000 events
# 129000 events
# 130000 events
# 131000 events
# 132000 events
# 133000 events
# 134000 events
# 135000 events
# 136000 events
# 137000 events
# 137000 events
# 138000 events
# 139000 events
# 139000 events
# 139000 events
# 139000 events
# 139000 events
# 140000 events
# 141000 events
# 142000 events
# 143000 events
# 143000 events
# 144000 events
# 145000 events
# 146000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 147000 events
# 148000 events
# 148000 events
# 149000 events
# 150000 events
# 150000 events
# 150000 events
# 150000 events
# 151000 events
# 152000 events
# 152000 events
# 153000 events
# 153000 events
# 153000 events
# 153000 events
# 153000 events
# 153000 events
# 154000 events
# 154000 events
# 155000 events
# 156000 events
# 157000 events
# 157000 events
# 158000 events
# 158000 events
# 159000 events
# 160000 events
# 161000 events
# 162000 events
# 162000 events
# 162000 events
# 162000 events
# 163000 events
# 163000 events
# 164000 events
# 165000 events
# 166000 events
# 167000 events
# 168000 events
# 168000 events
# 168000 events
# 169000 events
# 169000 events
# 169000 events
# 170000 events
# 170000 events
# 170000 events
# 170000 events
# 171000 events
# 172000 events
# 173000 events
# 173000 events
# 174000 events
# 175000 events
# 175000 events
# 176000 events
# 176000 events
# 177000 events
# 177000 events
# 178000 events
# 179000 events
# 180000 events
# 180000 events
# 181000 events
# 181000 events
# 181000 events
# 181000 events
# 181000 events
# 181000 events
# 182000 events
# 183000 events
# 183000 events
# 184000 events
# 184000 events
# 184000 events
# 185000 events
# 186000 events
# 187000 events
# 187000 events
# 188000 events
# 189000 events
# 189000 events
# 189000 events
# 189000 events
# 190000 events
# 191000 events
# 192000 events
# 192000 events
# 192000 events
# 193000 events
# 193000 events
# 194000 events
# 195000 events
# 196000 events
# 196000 events
# 197000 events
# 198000 events
# 199000 events
# 199000 events
# 200000 events
# 201000 events
# 202000 events
# 203000 events
# 203000 events
# 204000 events
# 205000 events
# 206000 events
# 207000 events
# 207000 events
# 208000 events
# 209000 events
# 210000 events
# 210000 events
# 210000 events
# 211000 events
# 212000 events
# 213000 events
# 213000 events
# 214000 events
# 214000 events
# 215000 events
# 216000 events
# 216000 events
# 217000 events
# 217000 events
# 217000 events
# 218000 events
# 218000 events
# 219000 events
# 219000 events
# 219000 events
# 220000 events
# 220000 events
# 220000 events
# 220000 events
# 220000 events
# 220000 events
# 221000 events
# 221000 events
# 222000 events
# 222000 events
# 223000 events
# 224000 events
# 225000 events
# 225000 events
# 225000 events
# 225000 events
# 226000 events
# 226000 events
# 226000 events
# 227000 events
# 228000 events
# 229000 events
# 230000 events
# 231000 events
# 231000 events
# 231000 events
# 231000 events
# 231000 events
# 232000 events
# 232000 events
# 233000 events
# 233000 events
# 233000 events
# 233000 events
# 234000 events
# 234000 events
# 235000 events
# 236000 events
# 237000 events
# 238000 events
# 239000 events
# 240000 events
# 240000 events
# 240000 events
# 241000 events
# 242000 events
# 243000 events
# 243000 events
# 243000 events
# 244000 events
# 244000 events
# 244000 events
# 245000 events
# 245000 events
# 245000 events
# 246000 events
# 246000 events
# 246000 events
# 246000 events
# 246000 events
# 246000 events
# 247000 events
# 247000 events
# 247000 events
# 247000 events
# 248000 events
# 249000 events
# 250000 events
# 250000 events
# 250000 events
# 250000 events
# 250000 events
# 251000 events
# 251000 events
# 251000 events
# 251000 events
# 252000 events
# 253000 events
# 253000 events
# 254000 events
# 254000 events
# 255000 events
# 256000 events
# 257000 events
# 258000 events
# 258000 events
# 258000 events
# 258000 events
# 258000 events
# 259000 events
# 260000 events
# 261000 events
# 262000 events
# 263000 events
# 264000 events
# 264000 events
# 265000 events
# 266000 events
# 267000 events
# 267000 events
# 268000 events
# 269000 events
# 269000 events
# 269000 events
# 269000 events
# 270000 events
# 270000 events
# 271000 events
# 272000 events
# 272000 events
# 273000 events
# 273000 events
# 273000 events
# 273000 events
# 273000 events
# 274000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 275000 events
# 276000 events
# 277000 events
# 277000 events
# 278000 events
# 279000 events
# 280000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 281000 events
# 282000 events
# 283000 events
# 284000 events
# 285000 events
# 285000 events
# 286000 events
# 286000 events
# 287000 events
# 288000 events
# 289000 events
# 289000 events
# 290000 events
# 291000 events
# 292000 events
# 292000 events
# 292000 events
# 292000 events
# 293000 events
# 294000 events
# 295000 events
# 295000 events
# 295000 events
# 295000 events
# 296000 events
# 296000 events
# 296000 events
# 297000 events
# 298000 events
# 298000 events
# 299000 events
# 300000 events
# 301000 events
# 301000 events
# 302000 events
# 303000 events
# 304000 events
# 305000 events
# 306000 events
# 307000 events
# 307000 events
# 307000 events
# 308000 events
# 309000 events
# 310000 events
# 310000 events
# 311000 events
# 311000 events
# 312000 events
# 313000 events
# 313000 events
# 313000 events
# 313000 events
# 314000 events
# 314000 events
# 315000 events
# 315000 events
# 316000 events
# 316000 events
# 316000 events
# 317000 events
# 318000 events
# 318000 events
# 318000 events
# 319000 events
# 320000 events
# 320000 events
# 320000 events
# 320000 events
# 321000 events
# 322000 events
# 323000 events
# 323000 events
# 323000 events
# 324000 events
# 325000 events
# 326000 events
# 326000 events
# 326000 events
# 326000 events
# 327000 events
# 328000 events
# 329000 events
# 329000 events
# 329000 events
# 329000 events
# 329000 events
# 330000 events
# 330000 events
# 331000 events
# 332000 events
# 332000 events
# 333000 events
# 333000 events
# 333000 events
# 333000 events
# 334000 events
# 335000 events
# 335000 events
# 335000 events
# 336000 events
# 337000 events
# 337000 events
# 337000 events
# 338000 events
# 338000 events
# 339000 events
# 339000 events
# 340000 events
# 341000 events
# 342000 events
# 343000 events
# 343000 events
# 343000 events
# 343000 events
# 344000 events
# 345000 events
# 345000 events
# 346000 events
# 347000 events
# 348000 events
# 348000 events
# 349000 events
# 350000 events
# 351000 events
# 351000 events
# 352000 events
# 352000 events
# 352000 events
# 353000 events
# 354000 events
# 354000 events
# 355000 events
# 355000 events
# 355000 events
# 356000 events
# 357000 events
# 358000 events
# 358000 events
# 359000 events
# 359000 events
# 359000 events
# 359000 events
# 359000 events
# 360000 events
# 361000 events
# 361000 events
# 361000 events
# 361000 events
# 361000 events
# 361000 events
# 362000 events
# 363000 events
# 364000 events
# 364000 events
# 364000 events
# 365000 events
# 365000 events
# 366000 events
# 366000 events
# 367000 events
# 367000 events
# 368000 events
# 368000 events
# 368000 events
# 368000 events
# 369000 events
# 370000 events
# 371000 events
# 372000 events
# 372000 events
# 373000 events
# 374000 events
# 375000 events
# 376000 events
# 376000 events
# 377000 events
# 377000 events
# 377000 events
# 378000 events
# 379000 events
# 379000 events
# 380000 events
# 380000 events
# 381000 events
# 382000 events
# 383000 events
# 383000 events
# 383000 events
# 384000 events
# 385000 events
# 385000 events
# 386000 events
# 387000 events
# 388000 events
# 388000 events
# 389000 events
# 390000 events
# 390000 events
# 390000 events
# 390000 events
# 391000 events
# 391000 events
# 392000 events
# 393000 events
# 393000 events
# 393000 events
# 393000 events
# 394000 events
# 395000 events
# 395000 events
# 396000 events
# 397000 events
# 398000 events
# 399000 events
# 400000 events
# 400000 events
# 400000 events
# 401000 events
# 402000 events
# 403000 events
# 404000 events
# 405000 events
# 406000 events
# 406000 events
# 407000 events
# 408000 events
# 409000 events
# 409000 events
# 410000 events
# 411000 events
# 411000 events
# 411000 events
# 412000 events
# 413000 events
# 413000 events
# 414000 events
# 415000 events
# 415000 events
# 416000 events
# 416000 events
# 416000 events
# 416000 events
# 417000 events
# 417000 events
# 417000 events
# 417000 events
# 418000 events
# 418000 events
# 419000 events
# 419000 events
# 420000 events
# 420000 events
# 420000 events
# 421000 events
# 421000 events
# 422000 events
# 422000 events
# 422000 events
# 422000 events
# 422000 events
# 423000 events
# 424000 events
# 424000 events
# 425000 events
# 425000 events
# 425000 events
# 426000 events
# 426000 events
# 427000 events
# 428000 events
# 429000 events
# 429000 events
# 430000 events
# 430000 events
# 431000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 432000 events
# 433000 events
# 433000 events
# 434000 events
# 434000 events
# 434000 events
# 435000 events
# 435000 events
# 436000 events
# 437000 events
# 437000 events
# 437000 events
# 438000 events
# 438000 events
# 438000 events
# 438000 events
# 438000 events
# 439000 events
# 439000 events
# 440000 events
# 441000 events
# 442000 events
# 443000 events
# 444000 events
# 444000 events
# 444000 events
# 445000 events
# 445000 events
# 446000 events
# 446000 events
# 447000 events
# 448000 events
# 448000 events
# 448000 events
# 449000 events
# 450000 events
# 451000 events
# 451000 events
# 451000 events
# 451000 events
# 451000 events
# 451000 events
# 452000 events
# 452000 events
# 452000 events
# 453000 events
# 453000 events
# 454000 events
# 454000 events
# 454000 events
# 455000 events
# 455000 events
# 456000 events
# 456000 events
# 456000 events
# 456000 events
# 456000 events
# 457000 events
# 457000 events
# 458000 events
# 458000 events
# 459000 events
# 460000 events
# 460000 events
# 460000 events
# 461000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 462000 events
# 463000 events
# 464000 events
# 464000 events
# 465000 events
# 466000 events
# 467000 events
# 468000 events
# 469000 events
# 470000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 471000 events
# 472000 events
# 473000 events
# 473000 events
# 473000 events
# 473000 events
# 473000 events
# 474000 events
# 474000 events
# 474000 events
# 475000 events
# 475000 events
# 476000 events
# 477000 events
# 478000 events
# 479000 events
# 479000 events
# 479000 events
# 479000 events
# 480000 events
# 480000 events
# 481000 events
# 481000 events
# 481000 events
# 481000 events
# 481000 events
# 481000 events
# 482000 events
# 482000 events
# 483000 events
# 484000 events
# 484000 events
# 484000 events
# 485000 events
# 486000 events
# 487000 events
# 487000 events
# 487000 events
# 487000 events
# 488000 events
# 489000 events
# 489000 events
# 490000 events
# 490000 events
# 491000 events
# 491000 events
# 491000 events
# 492000 events
# 493000 events
# 494000 events
# 495000 events
# 496000 events
# 497000 events
# 498000 events
# 498000 events
# 499000 events
# 499000 events
# 500000 events
# 500000 events
# 500000 events
# 501000 events
# 501000 events
# 501000 events
# 502000 events
# 503000 events
# 504000 events
# 504000 events
# 505000 events
# 505000 events
# 505000 events
# 505000 events
# 506000 events
# 507000 events
# 508000 events
# 509000 events
# 509000 events
# 510000 events
# 510000 events
# 510000 events
# 510000 events
# 511000 events
# 512000 events
# 512000 events
# 513000 events
# 514000 events
# 514000 events
# 515000 events
# 516000 events
# 517000 events
# 518000 events
# 519000 events
# 520000 events
# 520000 events
# 521000 events
# 522000 events
# 522000 events
# 523000 events
# 524000 events
# 524000 events
# 524000 events
# 524000 events
# 525000 events
# 526000 events
# 527000 events
# 527000 events
# 527000 events
# 528000 events
# 529000 events
# 530000 events
# 530000 events
# 530000 events
# 531000 events
# 532000 events
# 532000 events
# 532000 events
# 532000 events
# 533000 events
# 533000 events
# 534000 events
# 535000 events
# 535000 events
# 535000 events
# 535000 events
# 536000 events
# 537000 events
# 537000 events
# 538000 events
# 539000 events
# 540000 events
# 540000 events
# 541000 events
# 541000 events
# 542000 events
# 542000 events
# 543000 events
# 544000 events
# 544000 events
# 544000 events
# 544000 events
# 545000 events
# 546000 events
# 547000 events
# 548000 events
# 548000 events
# 549000 events
# 550000 events
# 551000 events
# 552000 events
# 553000 events
# 553000 events
# 554000 events
# 554000 events
# 555000 events
# 555000 events
# 556000 events
# 557000 events
# 557000 events
# 557000 events
# 557000 events
# 558000 events
# 559000 events
# 560000 events
# 560000 events
# 560000 events
# 561000 events
# 561000 events
# 561000 events
# 561000 events
# 562000 events
# 563000 events
# 563000 events
# 564000 events
# 565000 events
# 566000 events
# 566000 events
# 567000 events
# 567000 events
# 568000 events
# 568000 events
# 569000 events
# 570000 events
# 570000 events
# 570000 events
# 571000 events
# 571000 events
# 572000 events
# 573000 events
# 574000 events
# 574000 events
# 574000 events
# 575000 events
# 575000 events
# 576000 events
# 576000 events
# 577000 events
# 578000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 579000 events
# 580000 events
# 581000 events
# 581000 events
# 582000 events
# 582000 events
# 583000 events
# 583000 events
# 583000 events
# 583000 events
# 583000 events
# 584000 events
# 585000 events
# 586000 events
# 586000 events
# 586000 events
# 586000 events
# 587000 events
# 588000 events
# 589000 events
# 590000 events
# 590000 events
# 591000 events
# 592000 events
# 592000 events
# 593000 events
# 594000 events
# 595000 events
# 596000 events
# 596000 events
# 597000 events
# 598000 events
# 599000 events
# 599000 events
# 600000 events
# 601000 events
# 602000 events
# 603000 events
# 603000 events
# 604000 events
# 605000 events
# 606000 events
# 606000 events
# 607000 events
# 608000 events
# 608000 events
# 608000 events
# 609000 events
# 609000 events
# 610000 events
# 610000 events
# 611000 events
# 612000 events
# 612000 events
# 613000 events
# 614000 events
# 615000 events
# 616000 events
# 616000 events
# 617000 events
# 618000 events
# 619000 events
# 619000 events
# 620000 events
# 620000 events
# 621000 events
# 622000 events
# 623000 events
# 624000 events
# 624000 events
# 624000 events
# 625000 events
# 625000 events
# 626000 events
# 626000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 627000 events
# 628000 events
# 628000 events
# 628000 events
# 628000 events
# 629000 events
# 630000 events
# 631000 events
# 631000 events
# 631000 events
# 632000 events
# 632000 events
# 633000 events
# 633000 events
# 634000 events
# 634000 events
# 635000 events
# 635000 events
# 636000 events
# 637000 events
# 637000 events
# 637000 events
# 637000 events
# 637000 events
# 637000 events
# 638000 events
# 638000 events
# 639000 events
# 640000 events
# 641000 events
# 642000 events
# 643000 events
# 644000 events
# 645000 events
# 646000 events
# 646000 events
# 647000 events
# 647000 events
# 648000 events
# 649000 events
# 650000 events
# 650000 events
# 650000 events
# 651000 events
# 652000 events
# 653000 events
# 654000 events
# 654000 events
# 654000 events
# 654000 events
# 655000 events
# 655000 events
# 656000 events
# 657000 events
# 657000 events
# 657000 events
# 658000 events
# 658000 events
# 659000 events
# 660000 events
# 661000 events
# 662000 events
# 663000 events
# 663000 events
# 663000 events
# 663000 events
# 664000 events
# 665000 events
# 665000 events
# 666000 events
# 667000 events
# 667000 events
# 668000 events
# 669000 events
# 669000 events
# 670000 events
# 670000 events
# 671000 events
# 671000 events
# 672000 events
# 673000 events
# 673000 events
# 674000 events
# 674000 events
# 675000 events
# 676000 events
# 676000 events
# 676000 events
# 677000 events
# 678000 events
# 679000 events
# 679000 events
# 680000 events
# 681000 events
# 682000 events
# 682000 events
# 682000 events
# 683000 events
# 683000 events
# 684000 events
# 685000 events
# 686000 events
# 686000 events
# 687000 events
# 687000 events
# 687000 events
# 687000 events
# 688000 events
# 688000 events
# 689000 events
# 689000 events
# 690000 events
# 691000 events
# 691000 events
# 691000 events
# 691000 events
# 692000 events
# 693000 events
# 694000 events
# 695000 events
# 695000 events
# 696000 events
# 696000 events
# 697000 events
# 697000 events
# 698000 events
# 698000 events
# 699000 events
# 700000 events
# 701000 events
# 701000 events
# 702000 events
# 703000 events
# 703000 events
# 704000 events
# 704000 events
# 705000 events
# 705000 events
# 706000 events
# 706000 events
# 707000 events
# 707000 events
# 708000 events
# 708000 events
# 708000 events
# 709000 events
# 710000 events
# 711000 events
# 711000 events
# 711000 events
# 712000 events
# 713000 events
# 714000 events
# 715000 events
# 715000 events
# 716000 events
# 717000 events
# 718000 events
# 719000 events
# 720000 events
# 721000 events
# 721000 events
# 722000 events
# 723000 events
# 724000 events
# 725000 events
# 725000 events
# 726000 events
# 727000 events
# 728000 events
# 728000 events
# 729000 events
# 729000 events
# 730000 events
# 730000 events
# 731000 events
# 732000 events
# 733000 events
# 734000 events
# 735000 events
# 735000 events
# 735000 events
# 735000 events
# 736000 events
# 737000 events
# 737000 events
# 738000 events
# 739000 events
# 740000 events
# 740000 events
# 740000 events
# 741000 events
# 742000 events
# 743000 events
# 744000 events
# 745000 events
# 745000 events
# 746000 events
# 747000 events
# 747000 events
# 748000 events
# 749000 events
# 750000 events
# 751000 events
# 751000 events
# 751000 events
# 752000 events
# 753000 events
# 753000 events
# 754000 events
# 754000 events
# 754000 events
# 754000 events
# 755000 events
# 755000 events
# 756000 events
# 757000 events
# 758000 events
# 758000 events
# 758000 events
# 759000 events
# 759000 events
# 760000 events
# 760000 events
# 760000 events
# 761000 events
# 761000 events
# 762000 events
# 762000 events
# 762000 events
# 763000 events
# 763000 events
# 764000 events
# 765000 events
# 766000 events
# 767000 events
# 768000 events
# 768000 events
# 769000 events
# 769000 events
# 769000 events
# 769000 events
# 769000 events
# 769000 events
# 770000 events
# 771000 events
# 771000 events
# 772000 events
# 772000 events
# 772000 events
# 773000 events
# 774000 events
# 775000 events
# 775000 events
# 775000 events
# 775000 events
# 776000 events
# 776000 events
# 776000 events
# 777000 events
# 777000 events
# 778000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 779000 events
# 780000 events
# 781000 events
# 781000 events
# 782000 events
# 783000 events
# 783000 events
# 783000 events
# 784000 events
# 784000 events
# 784000 events
# 784000 events
# 784000 events
# 785000 events
# 785000 events
# 786000 events
# 786000 events
# 787000 events
# 788000 events
# 788000 events
# 788000 events
# 789000 events
# 790000 events
# 791000 events
# 791000 events
# 792000 events
# 792000 events
# 793000 events
# 793000 events
# 793000 events
# 793000 events
# 794000 events
# 795000 events
# 796000 events
# 797000 events
# 798000 events
# 798000 events
# 799000 events
# 800000 events
# 800000 events
# 801000 events
# 801000 events
# 802000 events
# 803000 events
# 804000 events
# 804000 events
# 804000 events
# 804000 events
# 805000 events
# 806000 events
# 807000 events
# 807000 events
# 807000 events
# 807000 events
# 808000 events
# 808000 events
# 808000 events
# 808000 events
# 809000 events
# 809000 events
# 809000 events
# 810000 events
# 810000 events
# 811000 events
# 812000 events
# 813000 events
# 814000 events
# 815000 events
# 815000 events
# 815000 events
# 816000 events
# 817000 events
# 818000 events
# 819000 events
# 820000 events
# 821000 events
# 822000 events
# 823000 events
# 823000 events
# 823000 events
# 824000 events
# 824000 events
# 825000 events
# 825000 events
# 826000 events
# 827000 events
# 827000 events
# 827000 events
# 828000 events
# 829000 events
# 830000 events
# 831000 events
# 832000 events
# 832000 events
# 833000 events
# 833000 events
# 834000 events
# 834000 events
# 835000 events
# 835000 events
# 835000 events
# 836000 events
# 837000 events
# 838000 events
# 839000 events
# 839000 events
# 839000 events
# 840000 events
# 840000 events
# 841000 events
# 841000 events
# 842000 events
# 843000 events
# 843000 events
# 843000 events
# 844000 events
# 844000 events
# 845000 events
# 846000 events
# 847000 events
# 847000 events
# 848000 events
# 848000 events
# 849000 events
# 849000 events
# 849000 events
# 850000 events
# 850000 events
# 850000 events
# 850000 events
# 850000 events
# 850000 events
# 851000 events
# 851000 events
# 852000 events
# 853000 events
# 854000 events
# 854000 events
# 855000 events
# 855000 events
# 856000 events
# 856000 events
# 857000 events
# 858000 events
# 858000 events
# 859000 events
# 860000 events
# 860000 events
# 861000 events
# 861000 events
# 861000 events
# 861000 events
# 862000 events
# 862000 events
# 862000 events
# 863000 events
# 864000 events
# 865000 events
# 866000 events
# 867000 events
# 867000 events
# 868000 events
# 869000 events
# 869000 events
# 869000 events
# 870000 events
# 870000 events
# 870000 events
# 870000 events
# 870000 events
# 870000 events
# 871000 events
# 871000 events
# 872000 events
# 873000 events
# 873000 events
# 874000 events
# 874000 events
# 874000 events
# 875000 events
# 876000 events
# 877000 events
# 878000 events
# 879000 events
# 880000 events
# 880000 events
# 881000 events
# 882000 events
# 883000 events
# 884000 events
# 884000 events
# 884000 events
# 885000 events
# 885000 events
# 886000 events
# 886000 events
# 887000 events
# 888000 events
# 888000 events
# 889000 events
# 890000 events
# 891000 events
# 891000 events
# 891000 events
# 891000 events
# 892000 events
# 893000 events
# 894000 events
# 894000 events
# 895000 events
# 896000 events
# 897000 events
# 898000 events
# 899000 events
# 900000 events
# 900000 events
# 901000 events
# 901000 events
# 902000 events
# 903000 events
# 904000 events
# 905000 events
# 906000 events
# 906000 events
# 907000 events
# 907000 events
# 908000 events
# 908000 events
# 908000 events
# 909000 events
# 909000 events
# 910000 events
# 910000 events
# 911000 events
# 911000 events
# 911000 events
# 912000 events
# 913000 events
# 914000 events
# 914000 events
# 915000 events
# 915000 events
# 915000 events
# 916000 events
# 916000 events
# 917000 events
# 918000 events
# 918000 events
# 918000 events
# 918000 events
# 918000 events
# 919000 events
# 919000 events
# 920000 events
# 921000 events
# 922000 events
# 923000 events
# 923000 events
# 924000 events
# 925000 events
# 926000 events
# 926000 events
# 927000 events
# 927000 events
# 927000 events
# 928000 events
# 929000 events
# 930000 events
# 931000 events
# 932000 events
# 933000 events
# 934000 events
# 935000 events
# 935000 events
# 935000 events
# 936000 events
# 937000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 938000 events
# 939000 events
# 940000 events
# 940000 events
# 941000 events
# 942000 events
# 942000 events
# 942000 events
# 943000 events
# 943000 events
# 943000 events
# 944000 events
# 945000 events
# 946000 events
# 946000 events
# 947000 events
# 948000 events
# 949000 events
# 949000 events
# 949000 events
# 949000 events
# 950000 events
# 951000 events
# 952000 events
# 952000 events
# 953000 events
# 954000 events
# 954000 events
# 954000 events
# 954000 events
# 955000 events
# 955000 events
# 955000 events
# 955000 events
# 956000 events
# 957000 events
# 958000 events
# 959000 events
# 959000 events
# 960000 events
# 960000 events
# 960000 events
# 961000 events
# 962000 events
# 963000 events
# 964000 events
# 965000 events
# 965000 events
# 965000 events
# 966000 events
# 966000 events
# 967000 events
# 968000 events
# 969000 events
# 970000 events
# 971000 events
# 971000 events
# 971000 events
# 971000 events
# 972000 events
# 973000 events
# 974000 events
# 975000 events
# 976000 events
# 976000 events
# 977000 events
# 977000 events
# 978000 events
# 979000 events
# 980000 events
# 980000 events
# 980000 events
# 980000 events
# 980000 events
# 980000 events
# 981000 events
# 982000 events
# 982000 events
# 983000 events
# 983000 events
# 984000 events
# 985000 events
# 986000 events
# 987000 events
# 987000 events
# 987000 events
# 988000 events
# 988000 events
# 989000 events
# 990000 events
# 990000 events
# 991000 events
# 992000 events
# 992000 events
# 993000 events
# 994000 events
# 995000 events
# 996000 events
# 997000 events
# 998000 events
# 999000 events
# 1000000 events
# 1001000 events
# 1002000 events
# 1003000 events
# 1003000 events
# 1004000 events
# 1005000 events
# 1006000 events
# 1006000 events
# 1006000 events
# 1007000 events
# 1008000 events
# 1009000 events
# 1010000 events
# 1011000 events
# 1011000 events
# 1012000 events
# 1013000 events
# 1014000 events
# 1015000 events
# 1016000 events
# 1017000 events
# 1018000 events
# 1019000 events
# 1019000 events
# 1019000 events
# 1020000 events
# 1021000 events
# 1022000 events
# 1022000 events
# 1023000 events
# 1023000 events
# 1024000 events
# 1025000 events
# 1026000 events
# 1027000 events
# 1028000 events
# 1028000 events
# 1029000 events
# 1030000 events
# 1031000 events
# 1032000 events
# 1033000 events
# 1033000 events
# 1033000 events
# 1033000 events
# 1034000 events
# 1034000 events
# 1034000 events
# 1034000 events
# 1035000 events
# 1036000 events
# 1037000 events
# 1037000 events
# 1038000 events
# 1038000 events
# 1038000 events
# 1039000 events
# 1039000 events
# 1039000 events
# 1040000 events
# 1041000 events
# 1042000 events
# 1042000 events
# 1043000 events
# 1043000 events
# 1044000 events
# 1044000 events
# 1045000 events
# 1046000 events
# 1047000 events
# 1047000 events
# 1048000 events
# 1049000 events
# 1050000 events
# 1050000 events
# 1051000 events
# 1051000 events
# 1051000 events
# 1052000 events
# 1053000 events
# 1053000 events
# 1053000 events
# 1054000 events
# 1055000 events
# 1056000 events
# 1057000 events
# 1058000 events
# 1059000 events
# 1060000 events
# 1060000 events
# 1061000 events
# 1061000 events
# 1062000 events
# 1063000 events
# 1064000 events
# 1064000 events
# 1064000 events
# 1064000 events
# 1065000 events
# 1065000 events
# 1065000 events
# 1066000 events
# 1066000 events
# 1067000 events
# 1068000 events
# 1068000 events
# 1069000 events
# 1070000 events
# 1070000 events
# 1071000 events
# 1072000 events
# 1073000 events
# 1074000 events
# 1074000 events
# 1075000 events
# 1076000 events
# 1076000 events
# 1077000 events
# 1078000 events
# 1079000 events
# 1080000 events
# 1081000 events
# 1081000 events
# 1081000 events
# 1082000 events
# 1082000 events
# 1082000 events
# 1083000 events
# 1083000 events
# 1084000 events
# 1084000 events
# 1085000 events
# 1086000 events
# 1086000 events
# 1087000 events
# 1087000 events
# 1088000 events
# 1088000 events
# 1088000 events
# 1089000 events
# 1090000 events
# 1091000 events
# 1092000 events
# 1092000 events
# 1093000 events
# 1094000 events
# 1095000 events
# 1095000 events
# 1096000 events
# 1096000 events
# 1096000 events
# 1097000 events
# 1098000 events
# 1098000 events
# 1099000 events
# 1099000 events
# 1100000 events
# 1100000 events
# 1101000 events
# 1101000 events
# 1102000 events
# 1102000 events
# 1102000 events
# 1102000 events
# 1103000 events
# 1104000 events
# 1105000 events
# 1106000 events
# 1107000 events
# 1107000 events
# 1108000 events
# 1108000 events
# 1109000 events
# 1110000 events
# 1111000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1112000 events
# 1113000 events
# 1114000 events
# 1114000 events
# 1114000 events
# 1114000 events
# 1114000 events
# 1115000 events
# 1116000 events
# 1117000 events
# 1118000 events
# 1118000 events
# 1118000 events
# 1119000 events
# 1120000 events
# 1121000 events
# 1122000 events
# 1122000 events
# 1122000 events
# 1123000 events
# 1124000 events
# 1125000 events
# 1126000 events
# 1126000 events
# 1126000 events
# 1126000 events
# 1126000 events
# 1127000 events
# 1127000 events
# 1128000 events
# 1129000 events
# 1130000 events
# 1131000 events
# 1131000 events
# 1132000 events
# 1133000 events
# 1134000 events
# 1135000 events
# 1135000 events
# 1136000 events
# 1137000 events
# 1137000 events
# 1137000 events
# 1138000 events
# 1139000 events
# 1140000 events
# 1141000 events
# 1141000 events
# 1142000 events
# 1143000 events
# 1143000 events
# 1144000 events
# 1145000 events
# 1145000 events
# 1146000 events
# 1146000 events
# 1146000 events
# 1147000 events
# 1147000 events
# 1148000 events
# 1149000 events
# 1150000 events
# 1150000 events
# 1150000 events
# 1151000 events
# 1151000 events
# 1151000 events
# 1152000 events
# 1152000 events
# 1152000 events
# 1152000 events
# 1153000 events
# 1154000 events
# 1154000 events
# 1155000 events
# 1155000 events
# 1155000 events
# 1156000 events
# 1157000 events
# 1157000 events
# 1158000 events
# 1159000 events
# 1160000 events
# 1161000 events
# 1162000 events
# 1162000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1163000 events
# 1164000 events
# 1164000 events
# 1165000 events
# 1165000 events
# 1166000 events
# 1167000 events
# 1167000 events
# 1167000 events
# 1168000 events
# 1169000 events
# 1169000 events
# 1169000 events
# 1170000 events
# 1171000 events
# 1172000 events
# 1172000 events
# 1173000 events
# 1173000 events
# 1174000 events
# 1174000 events
# 1175000 events
# 1176000 events
# 1176000 events
# 1177000 events
# 1177000 events
# 1177000 events
# 1178000 events
# 1178000 events
# 1179000 events
# 1180000 events
# 1181000 events
# 1181000 events
# 1182000 events
# 1182000 events
# 1183000 events
# 1184000 events
# 1185000 events
# 1185000 events
# 1185000 events
# 1186000 events
# 1187000 events
# 1187000 events
# 1188000 events
# 1188000 events
# 1188000 events
# 1188000 events
# 1189000 events
# 1189000 events
# 1190000 events
# 1191000 events
# 1191000 events
# 1191000 events
# 1192000 events
# 1192000 events
# 1192000 events
# 1193000 events
# 1194000 events
# 1195000 events
# 1196000 events
# 1197000 events
# 1197000 events
# 1198000 events
# 1199000 events
# 1200000 events
# 1200000 events
# 1201000 events
# 1202000 events
# 1202000 events
# 1202000 events
# 1202000 events
# 1202000 events
# 1203000 events
# 1203000 events
# 1204000 events
# 1204000 events
# 1205000 events
# 1205000 events
# 1206000 events
# 1206000 events
# 1207000 events
# 1207000 events
# 1208000 events
# 1209000 events
# 1210000 events
# 1210000 events
# 1211000 events
# 1212000 events
# 1213000 events
# 1213000 events
# 1214000 events
# 1214000 events
# 1215000 events
# 1215000 events
# 1216000 events
# 1217000 events
# 1218000 events
# 1219000 events
# 1220000 events
# 1220000 events
# 1220000 events
# 1221000 events
# 1222000 events
# 1223000 events
# 1224000 events
# 1224000 events
# 1225000 events
# 1226000 events
# 1227000 events
# 1228000 events
# 1229000 events
# 1229000 events
# 1229000 events
# 1230000 events
# 1230000 events
# 1230000 events
# 1230000 events
# 1231000 events
# 1231000 events
# 1232000 events
# 1233000 events
# 1234000 events
# 1235000 events
# 1236000 events
# 1237000 events
# 1237000 events
# 1238000 events
# 1238000 events
# 1239000 events
# 1240000 events
# 1240000 events
# 1241000 events
# 1242000 events
# 1242000 events
# 1243000 events
# 1243000 events
# 1244000 events
# 1244000 events
# 1244000 events
# 1245000 events
# 1246000 events
# 1246000 events
# 1247000 events
# 1248000 events
# 1248000 events
# 1249000 events
# 1250000 events
# 1251000 events
# 1252000 events
# 1252000 events
# 1253000 events
# 1253000 events
# 1254000 events
# 1254000 events
# 1255000 events
# 1256000 events
# 1257000 events
# 1257000 events
# 1257000 events
# 1257000 events
# 1257000 events
# 1258000 events
# 1259000 events
# 1259000 events
# 1259000 events
# 1259000 events
# 1259000 events
# 1260000 events
# 1261000 events
# 1261000 events
# 1262000 events
# 1263000 events
# 1263000 events
# 1263000 events
# 1264000 events
# 1264000 events
# 1265000 events
# 1266000 events
# 1266000 events
# 1266000 events
# 1266000 events
# 1267000 events
# 1268000 events
# 1268000 events
# 1269000 events
# 1269000 events
# 1270000 events
# 1270000 events
# 1271000 events
# 1271000 events
# 1271000 events
# 1272000 events
# 1273000 events
# 1274000 events
# 1274000 events
# 1275000 events
# 1276000 events
# 1276000 events
# 1277000 events
# 1277000 events
# 1277000 events
# 1278000 events
# 1278000 events
# 1279000 events
# 1280000 events
# 1281000 events
# 1282000 events
# 1283000 events
# 1284000 events
# 1284000 events
# 1284000 events
# 1285000 events
# 1285000 events
# 1286000 events
# 1287000 events
# 1288000 events
# 1288000 events
# 1289000 events
# 1290000 events
# 1291000 events
# 1291000 events
# 1291000 events
# 1292000 events
# 1293000 events
# 1293000 events
# 1294000 events
# 1294000 events
# 1295000 events
# 1296000 events
# 1297000 events
# 1297000 events
# 1298000 events
# 1298000 events
# 1298000 events
# 1298000 events
# 1298000 events
# 1299000 events
# 1299000 events
# 1299000 events
# 1299000 events
# 1300000 events
# 1300000 events
# 1301000 events
# 1301000 events
# 1302000 events
# 1302000 events
# 1302000 events
# 1303000 events
# 1303000 events
# 1304000 events
# 1305000 events
# 1305000 events
# 1305000 events
# 1306000 events
# 1307000 events
# 1308000 events
# 1309000 events
# 1309000 events
# 1309000 events
# 1310000 events
# 1310000 events
# 1310000 events
# 1310000 events
# 1311000 events
# 1312000 events
# 1313000 events
# 1313000 events
# 1314000 events
# 1314000 events
# 1314000 events
# 1315000 events
# 1315000 events
# 1315000 events
# 1316000 events
# 1316000 events
# 1317000 events
# 1318000 events
# 1319000 events
# 1319000 events
# 1320000 events
# 1321000 events
# 1322000 events
# 1322000 events
# 1323000 events
# 1324000 events
# 1325000 events
# 1326000 events
# 1327000 events
# 1327000 events
# 1328000 events
# 1328000 events
# 1329000 events
# 1330000 events
# 1331000 events
# 1332000 events
# 1332000 events
# 1333000 events
# 1333000 events
# 1334000 events
# 1334000 events
# 1335000 events
# 1336000 events
# 1337000 events
# 1337000 events
# 1338000 events
# 1338000 events
# 1339000 events
# 1340000 events
# 1340000 events
# 1341000 events
# 1342000 events
# 1342000 events
# 1342000 events
# 1342000 events
# 1343000 events
# 1344000 events
# 1345000 events
# 1345000 events
# 1346000 events
# 1347000 events
# 1348000 events
# 1349000 events
# 1350000 events
# 1351000 events
# 1351000 events
# 1352000 events
# 1353000 events
# 1353000 events
# 1353000 events
# 1354000 events
# 1354000 events
# 1355000 events
# 1356000 events
# 1357000 events
# 1357000 events
# 1358000 events
# 1358000 events
# 1359000 events
# 1360000 events
# 1360000 events
# 1360000 events
# 1360000 events
# 1361000 events
# 1361000 events
# 1361000 events
# 1362000 events
# 1362000 events
# 1363000 events
# 1364000 events
# 1365000 events
# 1365000 events
# 1365000 events
# 1366000 events
# 1367000 events
# 1368000 events
# 1369000 events
# 1370000 events
# 1370000 events
# 1371000 events
# 1372000 events
# 1372000 events
# 1373000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1374000 events
# 1375000 events
# 1376000 events
# 1377000 events
# 1378000 events
# 1379000 events
# 1379000 events
# 1380000 events
# 1381000 events
# 1382000 events
# 1382000 events
# 1382000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1383000 events
# 1384000 events
# 1384000 events
# 1384000 events
# 1384000 events
# 1385000 events
# 1385000 events
# 1385000 events
# 1385000 events
# 1386000 events
# 1386000 events
# 1386000 events
# 1387000 events
# 1388000 events
# 1389000 events
# 1389000 events
# 1390000 events
# 1391000 events
# 1391000 events
# 1392000 events
# 1392000 events
# 1393000 events
# 1393000 events
# 1393000 events
# 1394000 events
# 1394000 events
# 1394000 events
# 1394000 events
# 1395000 events
# 1395000 events
# 1396000 events
# 1397000 events
# 1398000 events
# 1399000 events
# 1400000 events
# 1400000 events
# 1401000 events
# 1402000 events
# 1402000 events
# 1402000 events
# 1403000 events
# 1404000 events
# 1404000 events
# 1404000 events
# 1405000 events
# 1405000 events
# 1405000 events
# 1406000 events
# 1406000 events
# 1407000 events
# 1408000 events
# 1409000 events
# 1410000 events
# 1410000 events
# 1411000 events
# 1412000 events
# 1412000 events
# 1413000 events
# 1413000 events
# 1414000 events
# 1415000 events
# 1416000 events
# 1416000 events
# 1416000 events
# 1417000 events
# 1418000 events
# 1419000 events
# 1419000 events
# 1420000 events
# 1421000 events
# 1422000 events
# 1423000 events
# 1423000 events
# 1424000 events
# 1424000 events
# 1425000 events
# 1426000 events
# 1427000 events
# 1428000 events
# 1428000 events
# 1428000 events
# 1428000 events
# 1429000 events
# 1430000 events
# 1431000 events
# 1431000 events
# 1432000 events
# 1433000 events
# 1434000 events
# 1434000 events
# 1434000 events
# 1435000 events
# 1435000 events
# 1436000 events
# 1437000 events
# 1438000 events
# 1438000 events
# 1439000 events
# 1439000 events
# 1440000 events
# 1441000 events
# 1441000 events
# 1442000 events
# 1442000 events
# 1442000 events
# 1442000 events
# 1443000 events
# 1443000 events
# 1444000 events
# 1445000 events
# 1446000 events
# 1447000 events
# 1448000 events
# 1448000 events
# 1448000 events
# 1448000 events
# 1449000 events
# 1450000 events
# 1451000 events
# 1452000 events
# 1452000 events
# 1452000 events
# 1453000 events
# 1453000 events
# 1454000 events
# 1455000 events
# 1456000 events
# 1457000 events
# 1458000 events
# 1459000 events
# 1460000 events
# 1461000 events
# 1462000 events
# 1463000 events
# 1464000 events
# 1465000 events
# 1465000 events
# 1465000 events
# 1466000 events
# 1467000 events
# 1468000 events
# 1469000 events
# 1469000 events
# 1469000 events
# 1470000 events
# 1471000 events
# 1472000 events
# 1472000 events
# 1472000 events
# 1473000 events
# 1474000 events
# 1475000 events
# 1476000 events
# 1477000 events
# 1477000 events
# 1477000 events
# 1477000 events
# 1477000 events
# 1478000 events
# 1479000 events
# 1479000 events
# 1480000 events
# 1481000 events
# 1482000 events
# 1482000 events
# 1483000 events
# 1483000 events
# 1483000 events
# 1484000 events
# 1485000 events
# 1486000 events
# 1487000 events
# 1488000 events
# 1488000 events
# 1488000 events
# 1488000 events
# 1489000 events
# 1490000 events
# 1490000 events
# 1490000 events
# 1491000 events
# 1492000 events
# 1493000 events
# 1493000 events
# 1494000 events
# 1495000 events
# 1496000 events
# 1497000 events
# 1498000 events
# 1498000 events
# 1499000 events
# 1500000 events
# 1500000 events
# 1500000 events
# 1500000 events
# 1500000 events
# 1501000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1502000 events
# 1503000 events
# 1504000 events
# 1504000 events
# 1505000 events
# 1506000 events
# 1507000 events
# 1507000 events
# 1508000 events
# 1508000 events
# 1509000 events
# 1509000 events
# 1509000 events
# 1510000 events
# 1511000 events
# 1512000 events
# 1513000 events
# 1513000 events
# 1513000 events
# 1514000 events
# 1514000 events
# 1515000 events
# 1516000 events
# 1517000 events
# 1518000 events
# 1518000 events
# 1518000 events
# 1518000 events
# 1519000 events
# 1520000 events
# 1520000 events
# 1521000 events
# 1521000 events
# 1522000 events
# 1523000 events
# 1523000 events
# 1523000 events
# 1524000 events
# 1525000 events
# 1525000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1526000 events
# 1527000 events
# 1527000 events
# 1528000 events
# 1528000 events
# 1528000 events
# 1529000 events
# 1530000 events
# 1531000 events
# 1532000 events
# 1532000 events
# 1533000 events
# 1533000 events
# 1534000 events
# 1534000 events
# 1535000 events
# 1535000 events
# 1536000 events
# 1537000 events
# 1537000 events
# 1537000 events
# 1538000 events
# 1539000 events
# 1539000 events
# 1540000 events
# 1541000 events
# 1542000 events
# 1543000 events
# 1543000 events
# 1543000 events
# 1543000 events
# 1544000 events
# 1545000 events
# 1546000 events
# 1547000 events
# 1547000 events
# 1548000 events
# 1549000 events
# 1549000 events
# 1550000 events
# 1550000 events
# 1551000 events
# 1552000 events
# 1553000 events
# 1554000 events
# 1554000 events
# 1554000 events
# 1555000 events
# 1555000 events
# 1556000 events
# 1557000 events
# 1558000 events
# 1559000 events
# 1559000 events
# 1559000 events
# 1560000 events
# 1561000 events
# 1561000 events
# 1562000 events
# 1562000 events
# 1563000 events
# 1563000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1564000 events
# 1565000 events
# 1566000 events
# 1567000 events
# 1568000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1569000 events
# 1570000 events
# End reading

# %%
file = open(f'AmBe_neutron_out.csv', 'r')

reader = csv.reader(file)

head = next(reader, None)
print(head)
head = next(reader, None)
print(head)

neutron_L = []
neutron_S = []

for row in reader:
    neutron_L.append(float(row[0]))
    neutron_S.append(float(row[1]))

neutron_L = np.array(neutron_L)
neutron_S = np.array(neutron_S)
# Out:
# ['EJ276_50x50_Data/AmBe channel 0, False events, cuts [0]']
# ['L [ch]', 'S[ch]']

# %%
file = open(f'AmBe_gamma_out.csv', 'r')

reader = csv.reader(file)

head = next(reader, None)
print(head)
head = next(reader, None)
print(head)

gamma_L = []
gamma_S = []

for row in reader:
    gamma_L.append(float(row[0]))
    gamma_S.append(float(row[1]))

gamma_L = np.array(gamma_L)
gamma_S = np.array(gamma_S)
# Out:
# ['EJ276_50x50_Data/AmBe channel 0, False events, cuts [0]']
# ['L [ch]', 'S[ch]']

# %%
from FoM import FoM

L = np.concatenate((neutron_L, gamma_L))
S = np.concatenate((neutron_S, gamma_S))

FoMs, FoM_edges = FoM(L, S, neutron_L, neutron_S, gamma_L, gamma_S, 0.2, 200, 6)

# %%
plt.figure()

plt.step(FoM_edges[:-1], FoMs, where='mid')

plt.xlabel('L (MeVee)')
plt.ylabel('FoM')
# plt.yscale('log')

plt.title('Figure of Merit')
plt.legend()
plt.grid(color='#CCCCCC', linestyle=':')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure()
plt.hist2d(L, S, [256,256], norm=colors.LogNorm(vmin=1))
plt.xlabel('L (MeVee)')
plt.ylabel('S')
plt.ylim(0.2,1)
plt.xlim(0,13)
plt.colorbar(label='Counts')
plt.show()

# %%
plt.hist2d(neutron_L, neutron_S, [256,256], norm=colors.LogNorm(vmin=1))
plt.xlabel('L (MeVee)')
plt.ylabel('S')
plt.colorbar(label='Counts')
plt.show()

# %%
plt.figure()

plt.hist(neutron_L, bins='auto', histtype='step')

plt.xlabel('L (MeVee)')
plt.ylabel('Counts')
plt.yscale('log')

plt.title('neutron light output spectrum')
# plt.legend()
plt.grid(color='#CCCCCC', linestyle=':')
plt.show()

# %%
plt.hist2d(gamma_L, gamma_S, [256,256], norm=colors.LogNorm(vmin=1))
plt.xlabel('L (MeVee)')
plt.ylabel('S')
plt.colorbar(label='Counts')
plt.xlim(left=0)
plt.ylim(top=1)
plt.show()

# %%
plt.figure()

plt.hist(gamma_L, bins='auto', histtype='step')

plt.xlabel('L (MeVee)')
plt.ylabel('Counts')
plt.yscale('log')

plt.title('gamma light output spectrum')
# plt.legend()
plt.grid(color='#CCCCCC', linestyle=':')
plt.show()

# %%
gamma_L_hist = np.histogram(gamma_L, bins='sqrt')

grad = savgol_filter(np.gradient(gamma_L_hist[0]), 20, 3)
# grad = np.gradient(hist[0])

popt, pcov = curve_fit(gaussian, gamma_L_hist[1][200:-1], grad[200:], [4,1,-1])

print(popt)

plt.figure()
plt.step(gamma_L_hist[1][200:-1], grad[200:])
plt.plot(gamma_L_hist[1][200:-1], gaussian(gamma_L_hist[1][200:-1], *popt))

plt.show()
# Out:
# [  4.18393816   0.23317879 -16.17395211]
