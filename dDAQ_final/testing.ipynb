# %%
import matplotlib.pyplot as plt
import numpy as np
from read_dat import *

file = read_dat("../Data/Cs137.dat")
# Out:
# init complete

# %%
file.lst_out(False, [0], True, False, filename='22Na_lst_out.csv')
# Out:
# 1000 events
# 2000 events
# 3000 events
# 4000 events
# 5000 events
# 6000 events
# 7000 events
# 8000 events
# 9000 events
# 10000 events
# 11000 events
# 12000 events
# 13000 events
# 14000 events
# 15000 events
# 16000 events
# 17000 events
# 18000 events
# 19000 events
# 20000 events
# 21000 events
# 22000 events
# 23000 events
# 24000 events
# 25000 events
# 26000 events
# /home/mkidson/gitRepos/dDAQ_dev/dDAQ_final/event.py:89: RuntimeWarning: invalid value encountered in scalar divide
#   return self.shortIntegral / self.longIntegral
# 27000 events
# 28000 events
# 29000 events
# 30000 events
# 31000 events
# 32000 events
# 33000 events
# 34000 events
# 35000 events
# 36000 events
# 37000 events
# 38000 events
# 39000 events
# 40000 events
# 41000 events
# 42000 events
# 43000 events
# 44000 events
# 45000 events
# 46000 events
# 47000 events
# 48000 events
# 49000 events
# 50000 events
# 51000 events
# 52000 events
# 53000 events
# 54000 events
# 55000 events
# 56000 events
# 57000 events
# 58000 events
# 59000 events
# 60000 events
# 61000 events
# 62000 events
# 63000 events
# 64000 events
# 65000 events
# 66000 events
# 67000 events
# 68000 events
# 69000 events
# 70000 events
# 71000 events
# 72000 events
# 73000 events
# 74000 events
# 75000 events
# 76000 events
# 77000 events
# 78000 events
# 79000 events
# 80000 events
# 81000 events
# 82000 events
# 83000 events
# 84000 events
# 85000 events
# 86000 events
# 87000 events
# 88000 events
# 89000 events
# 90000 events
# 91000 events
# 92000 events
# 93000 events
# 94000 events
# 95000 events
# 96000 events
# 97000 events
# 98000 events
# 99000 events
# 100000 events
# 101000 events
# 102000 events
# 103000 events
# 104000 events
# 105000 events
# 106000 events
# 107000 events
# 108000 events
# 109000 events
# 110000 events
# 111000 events
# 112000 events
# 113000 events
# 114000 events
# 115000 events
# 116000 events
# 117000 events
# 118000 events
# 119000 events
# 120000 events
# 121000 events
# 122000 events
# 123000 events
# 124000 events
# 125000 events
# 126000 events
# 127000 events
# 128000 events
# 129000 events
# 130000 events
# 131000 events
# 132000 events
# 133000 events
# 134000 events
# 135000 events
# 136000 events
# 137000 events
# 138000 events
# 139000 events
# 140000 events
# 141000 events
# 142000 events
# 143000 events
# 144000 events
# 145000 events
# 146000 events
# 147000 events
# 148000 events
# 149000 events
# 150000 events
# 151000 events
# 152000 events
# 153000 events
# 154000 events
# 155000 events
# 156000 events
# 157000 events
# 158000 events
# 159000 events
# 160000 events
# 161000 events
# 162000 events
# 163000 events
# 164000 events
# 165000 events
# 166000 events
# 167000 events
# 168000 events
# 169000 events
# 170000 events
# 171000 events
# 172000 events
# 173000 events
# 174000 events
# 175000 events
# 176000 events
# 177000 events
# 178000 events
# 179000 events
# 180000 events
# 181000 events
# 182000 events
# 183000 events
# 184000 events
# 185000 events
# 186000 events
# 187000 events
# 188000 events
# 189000 events
# 190000 events
# 191000 events
# 192000 events
# 193000 events
# 194000 events
# 195000 events
# 196000 events
# 197000 events
# 198000 events
# 199000 events
# 200000 events
# 201000 events
# 202000 events
# 203000 events
# 204000 events
# 205000 events
# 206000 events
# 207000 events
# 208000 events
# 209000 events
# 210000 events
# 211000 events
# 212000 events
# 213000 events
# 214000 events
# 215000 events
# 216000 events
# 217000 events
# 218000 events
# 219000 events
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file.lst_out(False, [0], True, False, filename='22Na_lst_out.csv')
#
# File ~/gitRepos/dDAQ_dev/dDAQ_final/read_dat.py:194, in read_dat.lst_out(self, events, ch, output, traces, cuts, inc, filename)
#     191         writer_trace[i].writerow(ev[ch[i]].get_trace())
#     193 if events > counter or events == False:
# --> 194     ev = self.read_event()
#     195     counter += 1
#     196     if counter % 1000 == 0:
#
# File ~/gitRepos/dDAQ_dev/dDAQ_final/read_dat.py:78, in read_dat.read_event(self)
#      76 y = np.array(np.frombuffer(self.inputFile.read(self.channelSizes[self.chActive[i]]*2), dtype=np.uint16), dtype=int)
#      77 traces[i]=y
# ---> 78 ev.append(event(self.eventCounter, self.chActive[i], self.eventTimeStamp, traces[i], self.CFD, [self.tStart/self.nsPerSample, self.tShort/self.nsPerSample, self.tLong/self.nsPerSample], self.baselineSamples))
#      79 if ev[i].get_fails() != [0,0,0,0,0]:  # Don't understand this
#      80     self.totFails[i] += 1
#
# File ~/gitRepos/dDAQ_dev/dDAQ_final/event.py:23, in event.__init__(self, event_id, ch, t0, trace, CFD, integrals, baseline)
#      20 self.trace = self.baseline-trace
#      21 self.__check_polarity()
# ---> 23 self.CFD = self.__cfd(*CFD)
#      24 self.istart = self.CFD[1] + integrals[0]
#      25 self.ishort = self.CFD[1] + integrals[1]
#
# File ~/gitRepos/dDAQ_dev/dDAQ_final/event.py:116, in event.__cfd(self, F, L, O)
#     114         #calculate CFD
#     115 		for i in range(O + L + 1, len(self.trace) - O - L - 1, 1):
# --> 116 			cfdArr[i] = np.sum(F * self.trace[i - L : i - 1] - self.trace[i - L - O : i - 1 - O])
#     117         #find the inflection point
#     118 		closest = np.argmin(np.subtract(cfdArr, np.roll(cfdArr, 1)))
#
# KeyboardInterrupt:

# %%
L=[[],[]]
S=[[],[]]
for i in range(500):#read 500 events
	event = file.read_event()
	for j in range(len(event)): #per channel
		S[j].append(event[j].get_pulse_shape())
		L[j].append(event[j].get_long_integral())
